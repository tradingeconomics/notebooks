# %% [markdown]
# Importing dependencies

# %%
import tradingeconomics as te

import os
os.chdir('..')
from helper import get_api_key

# %% [markdown]
# API login

# %%
te.login(get_api_key())
# Out:
# 'You are logged in as a 10D377002D63488:6E8511E3FE804EC'

# %% [markdown]
# Importing data

# %%
df = te.getCalendarData(output_type='df')

# %% [markdown]
# Data manipulation

# %%
df['Hour'] = df['Date'].apply(lambda x: x[11:])
df['Date'] = df['Date'].apply(lambda x: x[:10])

df = df[['Date', 'Hour', 'Country', 'Category', 'Event', 'Source', 'Actual', 'Previous', 'Forecast', ]]

df.sort_values(['Date', 'Hour'], inplace=True)

df.head(30)
# Out:
#           Date      Hour         Country  \
# 0   2020-12-17  00:00:00       Australia
# 1   2020-12-17  00:30:00       Australia
# 2   2020-12-17  00:30:00       Australia
# 3   2020-12-17  00:30:00       Australia
# 4   2020-12-17  00:30:00       Australia
# 5   2020-12-17  00:30:00       Australia
# 6   2020-12-17  00:30:00       Singapore
# 7   2020-12-17  00:30:00       Singapore
# 8   2020-12-17  01:00:00       Singapore
# 9   2020-12-17  03:30:00       Singapore
# 10  2020-12-17  05:30:00     Netherlands
# 11  2020-12-17  07:00:00  European Union
# 12  2020-12-17  07:00:00     Switzerland
# 13  2020-12-17  07:30:00       Indonesia
# 14  2020-12-17  07:30:00       Indonesia
# 15  2020-12-17  07:30:00       Indonesia
# 16  2020-12-17  07:45:00          France
# 17  2020-12-17  07:45:00          France
# 18  2020-12-17  08:00:00         Austria
# 19  2020-12-17  08:00:00         Austria
# 20  2020-12-17  08:00:00         Austria
# 21  2020-12-17  08:00:00         Austria
# 22  2020-12-17  08:00:00     Philippines
# 23  2020-12-17  08:00:00        Slovakia
# 24  2020-12-17  08:00:00        Slovakia
# 25  2020-12-17  08:30:00       Hong Kong
# 26  2020-12-17  08:30:00          Sweden
# 27  2020-12-17  08:30:00     Switzerland
# 28  2020-12-17  08:35:00          Taiwan
# 29  2020-12-17  09:00:00           Italy
#
#                                      Category                          Event  \
# 0                              New Home Sales         HIA New Home Sales MoM
# 1              Labor Force Participation Rate             Participation Rate
# 2                        Part Time Employment       Part Time Employment Chg
# 3                        Full Time Employment       Full Time Employment Chg
# 4                           Unemployment Rate              Unemployment Rate
# 5                           Employment Change              Employment Change
# 6   Domestic Exports of Non Oil (nodx) (%yoy)            Non-Oil Exports YoY
# 7      Exports of Non-oil Domestic Exports Of            Non-Oil Exports MoM
# 8                            Balance of Trade               Balance of Trade
# 9                           Unemployment Rate        Unemployment Rate Final
# 10                          Unemployment Rate              Unemployment Rate
# 11                          Car Registrations      New Car Registrations YoY
# 12                           Balance of Trade               Balance of Trade
# 13                              Interest Rate         Interest Rate Decision
# 14                               Lending Rate          Lending Facility Rate
# 15                      Deposit Interest Rate          Deposit Facility Rate
# 16                        Business Confidence            Business Confidence
# 17                 Business Climate Indicator     Business Climate Indicator
# 18                             Inflation Rate             Inflation Rate YoY
# 19                         Inflation Rate Mom             Inflation Rate MoM
# 20                 Harmonised Consumer Prices  Harmonised Inflation Rate YoY
# 21                 Harmonised Consumer Prices  Harmonised Inflation Rate MoM
# 22                              Interest Rate         Interest Rate Decision
# 23                 Harmonised Consumer Prices  Harmonised Inflation Rate MoM
# 24                 Harmonised Consumer Prices  Harmonised Inflation Rate YoY
# 25                          Unemployment Rate              Unemployment Rate
# 26                          Unemployment Rate              Unemployment Rate
# 27                              Interest Rate     SNB Interest Rate Decision
# 28                              Interest Rate         Interest Rate Decision
# 29                        Construction Output        Construction Output YoY
#
#                                                Source   Actual Previous  \
# 0                  Housing Industry Association (HIA)    15.2%    -1.3%
# 1                     Australian Bureau of Statistics    66.1%    65.8%
# 2                     Australian Bureau of Statistics     5.8K    81.7K
# 3                     Australian Bureau of Statistics    84.2K    98.7K
# 4                     Australian Bureau of Statistics     6.8%       7%
# 5                     Australian Bureau of Statistics    90.0K   180.3K
# 6                                Statistics Singapore    -4.9%    -3.1%
# 7                                Statistics Singapore    -3.8%    -5.4%
# 8                                Statistics Singapore   $3.93B   $4.35B
# 9                      Ministry of Manpower Singapore     3.6%     2.8%
# 10                             Statistics Netherlands       4%     4.3%
# 11  European Automobile Manufacturers Association ...     -12%    -7.8%
# 12                     Federal Customs Administration  CHF3.1B  CHF2.9B
# 13                                     Bank Indonesia    3.75%    3.75%
# 14                                     Bank Indonesia     4.5%     4.5%
# 15                                     Bank Indonesia       3%       3%
# 16                                      INSEE, France       93       92
# 17                                      INSEE, France     91.5     79.4
# 18                                 Statistics Austria     1.3%     1.3%
# 19                                 Statistics Austria     0.2%     0.1%
# 20                                 Statistics Austria     1.1%     1.1%
# 21                                 Statistics Austria     0.2%     0.2%
# 22                        Bangko Sentral ng Pilipinas       2%       2%
# 23          Statistical Office of the Slovak Republic     0.1%     0.1%
# 24          Statistical Office of the Slovak Republic     1.6%     1.6%
# 25        Census and Statistics Department, Hong Kong     6.3%     6.4%
# 26                                  Statistics Sweden     7.7%     7.8%
# 27                                Swiss National Bank   -0.75%   -0.75%
# 28     Central Bank of the Republic of China (Taiwan)   1.125%   1.125%
# 29           National Institute of Statistics (ISTAT)     1.6%     4.7%
#
#    Forecast
# 0
# 1       66%
# 2
# 3
# 4        7%
# 5       50K
# 6        2%
# 7      6.2%
# 8
# 9      3.6%
# 10
# 11
# 12
# 13    3.75%
# 14     4.5%
# 15       3%
# 16       93
# 17
# 18
# 19
# 20
# 21
# 22       2%
# 23     0.1%
# 24     1.5%
# 25
# 26     8.4%
# 27   -0.75%
# 28   1.125%
# 29
