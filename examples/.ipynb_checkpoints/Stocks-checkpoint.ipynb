# %% [markdown]
# Importing dependencies

# %%
import tradingeconomics as te
import matplotlib.pyplot as plt
import pandas as pd
import helper
import configparser as cp

# %matplotlib inline

# %% [markdown]
# Importing data

# %%
cfg = cp.ConfigParser()
cfg.read('tradingeconomics.cfg')
key = cfg['API']['key']
te.login(key)

raw_df = te.getHistorical(symbol=['KO:US', 'PEP:US'], initDate='2020-01-01')

coca_cola = raw_df.loc[raw_df['Symbol'] == 'KO:US']
pepsico = raw_df.loc[raw_df['Symbol'] == 'PEP:US']

# %% [markdown]
# Data manipulation

# %%
coca_cola = coca_cola[['Date', 'Close']].rename(columns={'Close': 'Coca-Cola'}, inplace=False)
pepsico = pepsico[['Date', 'Close']].rename(columns={'Close': 'PepsiCo'}, inplace=False)

df = pd.merge(coca_cola, pepsico, on='Date')

df['Date'] = pd.to_datetime(df['Date'], format="%d/%m/%Y")

df.sort_values(['Date'], inplace=True)
df.set_index('Date', inplace=True)

df
# Out:
#             Coca-Cola    PepsiCo
# Date
# 2020-01-08     54.350  134.69000
# 2020-01-09     55.340  134.73000
# 2020-01-10     55.530  134.52000
# 2020-01-13     56.130  136.52500
# 2020-01-14     56.000  136.59500
# ...               ...        ...
# 2020-11-30     51.600  144.23000
# 2020-12-01     52.040  146.07000
# 2020-12-02     52.110  144.62000
# 2020-12-03     52.780  144.45000
# 2020-12-04     53.225  145.19501
#
# [231 rows x 2 columns]

# %% [markdown]
# Plotting

# %%
plt.style.use('seaborn-paper')
ax = helper.plot_multi(df, figsize=(15, 5))
ax.set_title('Coca-Cola/PepsiCo Comparison', color='black', size=20)
plt.tight_layout()
