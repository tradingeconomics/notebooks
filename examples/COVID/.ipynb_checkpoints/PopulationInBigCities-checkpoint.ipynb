# %% [markdown]
# Importing dependencies

# %%
import tradingeconomics as te
import time
import matplotlib.pyplot as plt
import configparser as cp
import os

# %% [markdown]
# Importing data

# %%
config_file = os.path.abspath(os.path.join(os.path.dirname('__file__'), '..', 'tradingeconomics.cfg'))

cfg = cp.ConfigParser()
cfg.read(config_file)
key = cfg['API']['key']
te.login(key)

population_in_cities = te.getWBIndicator(series_code = 'EN.URB.MCTY.TL.ZS', output_type='df')
time.sleep(1)

covid_cases = te.getIndicatorData(country='all', indicators = 'coronavirus cases', output_type='df')
time.sleep(1)

population = te.getIndicatorData(country='all', indicators = 'population', output_type='df')

# %% [markdown]
# Data manipulation

# %%
population_in_cities = population_in_cities[['country', 'last']].rename(columns={'country': 'Country', 'last': 'Population in big cities (% of total)'}).set_index('Country')
covid_cases = covid_cases[['Country', 'LatestValue']].rename(columns={'LatestValue': 'Cases'}).set_index('Country')
population = population[['Country', 'LatestValue']].rename(columns={'LatestValue': 'Population'}).set_index('Country')

df = covid_cases.join(population_in_cities).join(population)
df['Cases per 1.000 people'] = df['Cases']/(df['Population']*1000)
df = df[['Cases per 1.000 people', 'Population in big cities (% of total)']]

df.sort_values(['Cases per 1.000 people', 'Population in big cities (% of total)'], ascending=False, inplace=True)
df.drop('World', inplace=True)
df = df.dropna().head(30)
df
# Out:
#                 Cases per 1.000 people  Population in big cities (% of total)
# Country
# Belgium                      50.798342                               27.01655
# Czech Republic               49.910300                               12.17282
# Armenia                      46.635690                               36.62683
# United States                42.960462                               46.48654
# Panama                       40.127725                               42.89931
# Georgia                      39.687097                               28.95794
# Switzerland                  39.146370                               16.12967
# Israel                       36.980328                               57.85522
# Spain                        35.703068                               25.70305
# Kuwait                       34.184286                               72.55604
# France                       33.701568                               22.85243
# Austria                      32.466591                               21.57625
# Argentina                    32.214775                               42.90403
# Brazil                       30.868827                               42.10456
# Netherlands                  30.775116                               12.39846
# Portugal                     30.403988                               41.40354
# Peru                         29.756154                               32.46559
# Chile                        29.063632                               35.47648
# Costa Rica                   27.932806                               27.31113
# Italy                        27.581660                               18.82522
# Serbia                       27.493678                               20.06799
# Poland                       26.698630                                4.67709
# Colombia                     26.669287                               43.93045
# Sweden                       26.017400                               15.63409
# United Kingdom               25.118290                               26.95946
# Romania                      24.963936                                9.36267
# Hungary                      23.730194                               18.05448
# Jordan                       22.191651                               20.87283
# Bulgaria                     21.701857                               18.30534
# Lebanon                      19.242899                               35.10758

# %% [markdown]
# Plotting

# %%
color_dict = {'Population in big cities (% of total)': 'orange', 'Cases per 1.000 people': 'grey'}

df.plot(
    figsize=(20, 9),
    kind='bar',
    zorder=3,
    color=[color_dict.get(x, '#333333') for x in df.columns],
    fontsize=12
)

ax = plt.gca()

plt.setp(
    ax.get_xticklabels(),
    rotation=45,
    ha='right',
    rotation_mode='anchor',
    fontsize=12
)

plt.yticks(list(plt.yticks()[0]) + [15])
ax.yaxis.grid(zorder=0)
ax.set_title('Coronavirus Cases x Population in Cities', color='black', size=20)
plt.xlabel('Country', fontsize=16)
plt.tight_layout()
