# %% [raw]
# Importing dependencies

# %%
import tradingeconomics as te
import pandas as pd

import matplotlib.pyplot as plt


import os
os.chdir('..')
from helper import get_api_key

# %% [raw]
# API login

# %%
te.login(get_api_key())
# Out:
# 'You are logged in as a 10D377002D63488:6E8511E3FE804EC'

# %% [raw]
# Importing data

# %%
raw_savings_df = te.getHistoricalData(country='portugal', indicator='Personal savings',initDate='2019-01-01', output_type='df')
raw_spendings_df = te.getHistoricalData(country='portugal', indicator='Personal Spending', initDate='2019-01-01', output_type='df')
raw_spendings_df
# Out:
#      Country           Category             DateTime  Value Frequency  \
# 0   Portugal  Personal Spending  2019-01-31T00:00:00    2.2   Monthly
# 1   Portugal  Personal Spending  2019-02-28T00:00:00    2.3   Monthly
# 2   Portugal  Personal Spending  2019-03-31T00:00:00    2.4   Monthly
# 3   Portugal  Personal Spending  2019-04-30T00:00:00    2.5   Monthly
# 4   Portugal  Personal Spending  2019-05-31T00:00:00    2.6   Monthly
# 5   Portugal  Personal Spending  2019-06-30T00:00:00    2.6   Monthly
# 6   Portugal  Personal Spending  2019-07-31T00:00:00    2.6   Monthly
# 7   Portugal  Personal Spending  2019-08-31T00:00:00    2.5   Monthly
# 8   Portugal  Personal Spending  2019-09-30T00:00:00    2.2   Monthly
# 9   Portugal  Personal Spending  2019-10-31T00:00:00    1.6   Monthly
# 10  Portugal  Personal Spending  2019-11-30T00:00:00    0.8   Monthly
# 11  Portugal  Personal Spending  2019-12-31T00:00:00   -0.4   Monthly
# 12  Portugal  Personal Spending  2020-01-31T00:00:00   -1.3   Monthly
# 13  Portugal  Personal Spending  2020-02-29T00:00:00   -2.9   Monthly
# 14  Portugal  Personal Spending  2020-03-31T00:00:00   -4.4   Monthly
# 15  Portugal  Personal Spending  2020-04-30T00:00:00   -5.8   Monthly
# 16  Portugal  Personal Spending  2020-05-31T00:00:00   -6.8   Monthly
# 17  Portugal  Personal Spending  2020-06-30T00:00:00   -7.2   Monthly
# 18  Portugal  Personal Spending  2020-07-31T00:00:00   -7.2   Monthly
# 19  Portugal  Personal Spending  2020-08-31T00:00:00   -6.7   Monthly
# 20  Portugal  Personal Spending  2020-09-30T00:00:00   -6.0   Monthly
# 21  Portugal  Personal Spending  2020-10-31T00:00:00   -5.1   Monthly
# 22  Portugal  Personal Spending  2020-11-30T00:00:00   -4.1   Monthly
# 23  Portugal  Personal Spending  2020-12-31T00:00:00   -3.0   Monthly
# 24  Portugal  Personal Spending  2021-01-31T00:00:00   -1.8   Monthly
# 25  Portugal  Personal Spending  2021-02-28T00:00:00   -0.6   Monthly
#
#    HistoricalDataSymbol           LastUpdate
# 0        PORTUGALPERSPE  2020-11-20T15:56:00
# 1        PORTUGALPERSPE  2020-08-23T16:25:00
# 2        PORTUGALPERSPE  2020-11-20T15:56:00
# 3        PORTUGALPERSPE  2020-11-20T15:56:00
# 4        PORTUGALPERSPE  2020-11-20T15:56:00
# 5        PORTUGALPERSPE  2020-11-20T15:56:00
# 6        PORTUGALPERSPE  2020-11-20T15:56:00
# 7        PORTUGALPERSPE  2020-12-18T13:19:00
# 8        PORTUGALPERSPE  2020-12-18T13:19:00
# 9        PORTUGALPERSPE  2020-12-18T13:19:00
# 10       PORTUGALPERSPE  2020-12-18T13:19:00
# 11       PORTUGALPERSPE  2020-12-18T13:19:00
# 12       PORTUGALPERSPE  2021-03-19T11:47:00
# 13       PORTUGALPERSPE  2021-03-19T11:47:00
# 14       PORTUGALPERSPE  2021-03-19T11:47:00
# 15       PORTUGALPERSPE  2021-03-19T11:47:00
# 16       PORTUGALPERSPE  2021-03-19T11:47:00
# 17       PORTUGALPERSPE  2021-03-19T11:47:00
# 18       PORTUGALPERSPE  2021-03-19T11:47:00
# 19       PORTUGALPERSPE  2021-03-19T11:47:00
# 20       PORTUGALPERSPE  2021-03-19T11:47:00
# 21       PORTUGALPERSPE  2021-03-19T11:47:00
# 22       PORTUGALPERSPE  2021-02-19T11:43:00
# 23       PORTUGALPERSPE  2021-03-19T11:47:00
# 24       PORTUGALPERSPE  2021-03-19T11:47:00
# 25       PORTUGALPERSPE  2021-03-19T11:43:00

# %% [raw]
# Data Manipulation

# %%
savings_df = raw_savings_df[['DateTime', 'Value']].rename(columns={'Value': 'Personal Savings(%)'})

savings_df['Date'] = pd.DatetimeIndex(savings_df['DateTime'])
savings_df.set_index('Date', inplace=True)
del savings_df['DateTime']


spending_df = raw_spendings_df[['DateTime', 'Value']].rename(columns={'Value': 'Personal Spending(%)'})

spending_df['Date'] = pd.DatetimeIndex(spending_df['DateTime'])
spending_df.set_index('Date', inplace=True)
del spending_df['DateTime']


df = pd.merge(spending_df,savings_df, on='Date')

df
# Out:
#             Personal Spending(%)  Personal Savings(%)
# Date
# 2019-03-31                   2.4                  6.5
# 2019-06-30                   2.6                  6.8
# 2019-09-30                   2.2                  7.0
# 2019-12-31                  -0.4                  7.0
# 2020-03-31                  -4.4                  7.5
# 2020-06-30                  -7.2                 10.6

# %% [raw]
# Plotting

# %%
fig, ax = plt.subplots(figsize=(15, 7))

plt.plot( df.index.tolist(), df['Personal Savings(%)'].values.tolist(), marker='', color='red', linewidth=2, label="Gross Household Saving Rate(%)")
plt.plot( df.index.tolist(), df['Personal Spending(%)'].values.tolist(),marker='', color='blue', linewidth=2, label="Private Consumption Rate(%)")


plt.legend(
          title="Legend",
          loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1),
          fontsize=12,
          ncol=1,
          title_fontsize=14,
          borderpad=1)


ax.xaxis.grid(True)
ynew = 0
ax.axhline(ynew, color='black')
plt.grid(True)

plt.title("Covid's impact on the French household economy", size=20)
plt.show()
