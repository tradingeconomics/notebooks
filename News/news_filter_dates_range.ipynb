# %%
import tradingeconomics as te

# %%
te.login()
# Out:
# 'You are logged in as a guest:guest'

# %% [markdown]
# ## News

# %% [markdown]
# ##### By start and end date

# %%
te.getNews(start_date='2021-02-02', end_date='2021-02-05', output_type='df')
# Out:
# https://api.tradingeconomics.com/news?c=guest:guest&d1=2021-02-02&d2=2021-02-05
#        id                                         title  \
# 0  137988          ASX Set for Best Week Since November
# 1  137987    Japan Household Spending Drops in December
# 2  137986  South Korea’s Current Account Surplus Widens
# 3  137985                  NZX Bounces Off Two-Week Low
# 4  137984                      Mexican Stocks Gain 0.5%
# 5  137982        Brazilian Equities Decline on Thursday
# 6  137980           S&P 500, Nasdaq Notch Fresh Records
# 7  137977          The Dow Jones Index increasing 0.81%
# 8  137976           Coffee Prices Remain Under Pressure
# 9  137975  Argentina Industrial Production Gains Steams
#
#                       date                                        description  \
# 0      2021-02-04T23:53:00  The benchmark S&P/ASX 200 rose above the 6,800...
# 1  2021-02-04T23:36:51.847  Household spending in Japan declined 0.6 perce...
# 2   2021-02-04T23:17:18.55  South Korea’s current account surplus widened ...
# 3      2021-02-04T22:45:00  New Zealand's main stock index has recouped so...
# 4      2021-02-04T21:40:00  Mexico’s IPC increased 211 points or 0.5% to 4...
# 5      2021-02-04T21:31:00  Brazilian equities snapped a three-session ral...
# 6      2021-02-04T21:04:00  Wall Street rose for the fourth session in a r...
# 7   2021-02-04T20:30:03.96  United States Stock Market is up by 249 points...
# 8  2021-02-04T20:05:02.897  Arabica coffee futures on ICE have been tradin...
# 9  2021-02-04T19:11:19.473  Industrial production in Argentina grew 4.9 pe...
#
#          country               category       symbol  \
# 0      Australia           Stock Market         AS51
# 1          Japan     Household Spending  JAPANHOUSPE
# 2    South Korea        Current Account       KOBPCB
# 3    New Zealand           Stock Market     NZSE50FG
# 4         Mexico           Stock Market       MEXBOL
# 5         Brazil           Stock Market         IBOV
# 6  United States           Stock Market         INDU
# 7  United States           Stock Market         INDU
# 8      Commodity              Commodity          KC1
# 9      Argentina  Industrial Production     ARIPNSYO
#
#                                 url
# 0           /australia/stock-market
# 1         /japan/household-spending
# 2      /south-korea/current-account
# 3         /new-zealand/stock-market
# 4              /mexico/stock-market
# 5              /brazil/stock-market
# 6       /united-states/stock-market
# 7       /united-states/stock-market
# 8                 /commodity/coffee
# 9  /argentina/industrial-production
