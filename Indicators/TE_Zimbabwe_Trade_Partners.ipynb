# %% [markdown]
# # Zimbabwe Trade Partners

# %%
import tradingeconomics as te
from wordcloud import WordCloud
from wordcloud import STOPWORDS
import matplotlib.pyplot as plt

# %%
te.login()
# Out:
# 'You are logged in as a jupyter:jupyter'

# %%
trading_partners = te.getCmtCountry(country = 'Zimbabwe', output_type='df')
trading_partners
# Out:
#            symbol  country1       country2    type  \
# 0     ZWEUSA01062  Zimbabwe  United States  Export
# 1     ZWEAGO00002  Zimbabwe         Angola  Export
# 2     ZWEZMB01062  Zimbabwe         Zambia  Export
# 3     ZWEAUS00002  Zimbabwe      Australia  Export
# 4     ZWEBWA84192  Zimbabwe       Botswana  Export
# ...           ...       ...            ...     ...
# 9995  ZWEUSA90011  Zimbabwe  United States  Import
# 9996  ZWEKOR84091  Zimbabwe    South Korea  Import
# 9997  ZWEZAF90011  Zimbabwe   South Africa  Import
# 9998  ZWEMOZ84091  Zimbabwe     Mozambique  Import
# 9999  ZWEALBXX901  Zimbabwe        Albania  Import
#
#                                                category  \
# 0                Animals, live, not specified elsewhere
# 1                                                  None
# 2                Animals, live, not specified elsewhere
# 3                                                  None
# 4     Apparatus for Treatment of Materials By Temper...
# ...

# %%
# imports
import_partners = trading_partners.loc[trading_partners['type'] == 'Import']
import_countries = import_partners['country2'].tolist()

# %% [markdown]
# ### Zimbabwe Import Partners

# %%
text = " ".join(i for i in import_countries)
wordcloud = WordCloud(background_color="white").generate(text)
plt.figure( figsize=(15,15))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# exports
export_partners = trading_partners.loc[trading_partners['type'] == 'Export']
export_countries = export_partners['country2'].tolist()

# %% [markdown]
# ### Zimbabwe Export Partners

# %%
text = " ".join(i for i in export_countries)
wordcloud = WordCloud(background_color="white").generate(text)
plt.figure( figsize=(15,15))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
