# %% [markdown]
# # Zimbabwe Trade Partners

# %%
import tradingeconomics as te
from wordcloud import WordCloud
from wordcloud import STOPWORDS
import matplotlib.pyplot as plt

# %%
te.login('jupyter:jupyter')
# Out:
# 'You are logged in as a jupyter:jupyter'

# %%
trading_partners = te.getCmtCountry(country = 'Zimbabwe', output_type='df')
trading_partners
# Out:
#            symbol  country1       country2    type  \
# 0     ZWEAGO00002  Zimbabwe         Angola  Export
# 1     ZWEUSA01062  Zimbabwe  United States  Export
# 2     ZWEAUS00002  Zimbabwe      Australia  Export
# 3     ZWEZMB01062  Zimbabwe         Zambia  Export
# 4     ZWEAUT00002  Zimbabwe        Austria  Export
# ...           ...       ...            ...     ...
# 9995  ZWEBWAXX481  Zimbabwe       Botswana  Import
# 9996  ZWESWZXX901  Zimbabwe      Swaziland  Import
# 9997  ZWECANXX481  Zimbabwe         Canada  Import
# 9998  ZWESYCXX901  Zimbabwe     Seychelles  Import
# 9999  ZWECHEXX481  Zimbabwe    Switzerland  Import
#
#                                                category  \
# 0                                                  None
# 1                Animals, live, not specified elsewhere
# 2                                                  None
# 3                Animals, live, not specified elsewhere
# 4                                                  None
# ...                                                 ...
# 9995  Paper and paperboard, articles of pulp, paper ...
# 9996       Optical, photo, technical, medical apparatus
# 9997  Paper and paperboard, articles of pulp, paper ...
# 9998       Optical, photo, technical, medical apparatus
# 9999  Paper and paperboard, articles of pulp, paper ...
#
#                                                     url  \
# 0                              /zimbabwe/exports/angola
# 1     /zimbabwe/exports/united-states/other-live-ani...
# 2                           /zimbabwe/exports/australia
# 3           /zimbabwe/exports/zambia/other-live-animals
# 4                             /zimbabwe/exports/austria
# ...                                                 ...
# 9995  /zimbabwe/imports/botswana/paper-paperboard-ar...
# 9996  /zimbabwe/imports/swaziland/optical-photo-tech...
# 9997  /zimbabwe/imports/canada/paper-paperboard-arti...
# 9998  /zimbabwe/imports/seychelles/optical-photo-tec...
# 9999  /zimbabwe/imports/switzerland/paper-paperboard...
#
#                                                   title           lastupdate
# 0                            Zimbabwe exports to Angola  2021-03-30T00:38:00
# 1     Zimbabwe exports of animals, live, not specifi...  2021-03-26T22:10:00
# 2                         Zimbabwe exports to Australia  2021-03-30T00:38:00
# 3     Zimbabwe exports of animals, live, not specifi...  2021-03-26T22:10:00
# 4                           Zimbabwe exports to Austria  2021-03-30T00:38:00
# ...                                                 ...                  ...
# 9995  Zimbabwe Imports from Botswana of Paper and pa...  2021-05-22T04:37:00
# 9996  Zimbabwe Imports from Swaziland of Optical, ph...  2021-05-22T05:32:00
# 9997  Zimbabwe Imports from Canada of Paper and pape...  2021-05-22T04:38:00
# 9998  Zimbabwe Imports from Seychelles of Optical, p...  2021-05-22T05:31:00
# 9999  Zimbabwe Imports from Switzerland of Paper and...  2021-05-22T05:32:00
#
# [10000 rows x 8 columns]

# %%
# imports
import_partners = trading_partners.loc[trading_partners['type'] == 'Import']
import_partners
# Out:
#            symbol  country1     country2    type  \
# 2227  ZWEABW00001  Zimbabwe        Aruba  Import
# 2229  ZWEAFG00001  Zimbabwe  Afghanistan  Import
# 2231  ZWEALB00001  Zimbabwe      Albania  Import
# 2233  ZWEAND00001  Zimbabwe      Andorra  Import
# 2235  ZWEBDI00001  Zimbabwe      Burundi  Import
# ...           ...       ...          ...     ...
# 9995  ZWEBWAXX481  Zimbabwe     Botswana  Import
# 9996  ZWESWZXX901  Zimbabwe    Swaziland  Import
# 9997  ZWECANXX481  Zimbabwe       Canada  Import
# 9998  ZWESYCXX901  Zimbabwe   Seychelles  Import
# 9999  ZWECHEXX481  Zimbabwe  Switzerland  Import
#
#                                                category  \
# 2227                                               None
# 2229                                               None
# 2231                                               None
# 2233                                               None
# 2235                                               None
# ...                                                 ...
# 9995  Paper and paperboard, articles of pulp, paper ...
# 9996       Optical, photo, technical, medical apparatus
# 9997  Paper and paperboard, articles of pulp, paper ...
# 9998       Optical, photo, technical, medical apparatus
# 9999  Paper and paperboard, articles of pulp, paper ...
#
#                                                     url  \
# 2227                            /zimbabwe/imports/aruba
# 2229                      /zimbabwe/imports/afghanistan
# 2231                          /zimbabwe/imports/albania
# 2233                          /zimbabwe/imports/andorra
# 2235                          /zimbabwe/imports/burundi
# ...                                                 ...
# 9995  /zimbabwe/imports/botswana/paper-paperboard-ar...
# 9996  /zimbabwe/imports/swaziland/optical-photo-tech...
# 9997  /zimbabwe/imports/canada/paper-paperboard-arti...
# 9998  /zimbabwe/imports/seychelles/optical-photo-tec...
# 9999  /zimbabwe/imports/switzerland/paper-paperboard...
#
#                                                   title           lastupdate
# 2227                        Zimbabwe imports from Aruba  2021-03-30T00:38:00
# 2229                  Zimbabwe imports from Afghanistan  2021-03-30T00:38:00
# 2231                      Zimbabwe imports from Albania  2021-03-30T00:38:00
# 2233                      Zimbabwe imports from Andorra  2021-03-30T00:38:00
# 2235                      Zimbabwe imports from Burundi  2021-03-30T00:38:00
# ...                                                 ...                  ...
# 9995  Zimbabwe Imports from Botswana of Paper and pa...  2021-05-22T04:37:00
# 9996  Zimbabwe Imports from Swaziland of Optical, ph...  2021-05-22T05:32:00
# 9997  Zimbabwe Imports from Canada of Paper and pape...  2021-05-22T04:38:00
# 9998  Zimbabwe Imports from Seychelles of Optical, p...  2021-05-22T05:31:00
# 9999  Zimbabwe Imports from Switzerland of Paper and...  2021-05-22T05:32:00
#
# [7759 rows x 8 columns]

# %%
import_countries = import_partners['country2'].tolist()
import_countries
# Out:
# ['Aruba',
#  'Afghanistan',
#  'Albania',
#  'Andorra',
#  'Burundi',
#  'Belgium',
#  'Benin',
#  'Burkina Faso',
#  'Bangladesh',
#  'Bulgaria',
#  'Bahrain',
#  'Bahamas',
#  'Bosnia And Herzegovina',
#  'Belarus',
#  'Belize',
#  'United Kingdom',
#  'Bermuda',
#  'India',
#  'United Arab Emirates',
#  'Mozambique',
#  'Argentina',
#  'United States',
#  'Brazil',
#  'South Africa',
#  'Barbados',
#  'Zambia',
#  'Botswana',
#  'United Arab Emirates',
#  'Central African Republic',
#  'China',
#  'Canada',
#  'Germany',
#  'Switzerland',
#  'South Africa',
#  'Chile',
#  'Zambia',
#  'China',
#  'China',
#  'Ivory Coast',
#  'United States',
#  'Cameroon',
#  'South Africa',
#  'Congo',
#  'United Arab Emirates',
#  'Republic of the Congo',
#  'Brazil',
#  'Colombia',
#  'Botswana',
#  'Australia',
#  'Switzerland',
#  'Austria',
#  'China',
#  'Cuba',
#  'Cyprus',
#  'Cayman Islands',
#  'Germany',
#  'Cyprus',
#  'France',
#  'Czech Republic',
#  'United Kingdom',
#  'Germany',
#  'Hong Kong',
#  'Denmark',
#  'Spain',
#  'Dominican Republic',
#  'India',
#  'Algeria',
#  'Ireland',
#  'Spain',
#  'Italy',
#  'Estonia',
#  'Mozambique',
#  'Ethiopia',
#  'Netherlands',
#  'Finland',
#  'Pakistan',
#  'Egypt',
#  'Poland',
#  'France',
#  'Turkey',
#  'Faroe Islands',
#  'United States',
#  'United Kingdom',
#  'South Africa',
#  'Georgia',
#  'Zambia',
#  'Ghana',
#  'United Arab Emirates',
#  'Guinea',
#  'Botswana',
#  'Greece',
#  'Canada',
#  'Guam',
#  'Switzerland',
#  'Hong Kong',
#  'China',
#  'Honduras',
#  'Germany',
#  'Croatia',
#  'United Kingdom',
#  'Hungary',
#  'Hong Kong',
#  'Indonesia',
#  'India',
#  'India',
#  'South Korea',
#  'Ireland',
#  'Netherlands',
#  'Iran',
#  'Sweden',
#  'Iraq',
#  'Seychelles',
#  'Iceland',
#  'Turkey',
#  'Israel',
#  'United States',
#  'Italy',
#  'South Africa',
#  'Jordan',
#  'Zambia',
#  'Japan',
#  'Albania',
#  'Kenya',
#  'United Arab Emirates',
#  'St Kitts and Nevis',
#  'Brazil',
#  'South Korea',
#  'Botswana',
#  'Kuwait',
#  'Canada',
#  'Cambodia',
#  'Switzerland',
#  'Lebanon',
#  'China',
#  'Liberia',
#  'Austria',
#  'Sri Lanka',
#  'Belgium',
#  'Lesotho',
#  'Germany',
#  'Lithuania',
#  'Denmark',
#  'Luxembourg',
#  'France',
#  'Latvia',
#  'Faroe Islands',
#  'Morocco',
#  'United Kingdom',
#  'Moldova',
#  'Egypt',
#  'Madagascar',
#  'Spain',
#  'Mexico',
#  'Greece',
#  'Mali',
#  'Hong Kong',
#  'Malta',
#  'India',
#  'Myanmar',
#  'Ireland',
#  'Mauritius',
#  'Italy',
#  'Malawi',
#  'Lebanon',
#  'Malaysia',
#  'Mozambique',
#  'Namibia',
#  'Namibia',
#  'Mozambique',
#  'Nigeria',
#  'Niger',
#  'Netherlands',
#  'Nigeria',
#  'Pakistan',
#  'Poland',
#  'Poland',
#  'North Korea',
#  'Portugal',
#  'Portugal',
#  'Singapore',
#  'Paraguay',
#  'Slovakia',
#  'Qatar',
#  'Sweden',
#  'Romania',
#  'Swaziland',
#  'Russia',
#  'Seychelles',
#  'Rwanda',
#  'Thailand',
#  'Saudi Arabia',
#  'Turkey',
#  'Sudan',
#  'South Africa',
#  'Senegal',
#  'Zambia',
#  'Singapore',
#  'Canada',
#  'New Zealand',
#  'Egypt',
#  'Oman',
#  'United Kingdom',
#  'Pakistan',
#  'Italy',
#  'Panama',
#  'Ukraine',
#  'Peru',
#  'United States',
#  'Philippines',
#  'Sudan',
#  'Netherlands',
#  'South Africa',
#  'Norway',
#  'United Arab Emirates',
#  'Sierra Leone',
#  'Botswana',
#  'Somalia',
#  'Canada',
#  'Serbia',
#  'China',
#  'Slovakia',
#  'Czech Republic',
#  'Slovenia',
#  'Denmark',
#  'Sweden',
#  'Egypt',
#  'Swaziland',
#  'France',
#  'Seychelles',
#  'United Kingdom',
#  'Chad',
#  'Hong Kong',
#  'Togo',
#  'Italy',
#  'Thailand',
#  'Kenya',
#  'East Timor',
#  'Mexico',
#  'Tunisia',
#  'Mauritius',
#  'Turkey',
#  'Sudan',
#  'Tanzania',
#  'United States',
#  'Uganda',
#  'World',
#  'Ukraine',
#  'South Africa',
#  'Uruguay',
#  'Zambia',
#  'United States',
#  'United Arab Emirates',
#  'Vietnam',
#  'Australia',
#  'World',
#  'Austria',
#  'South Africa',
#  'Botswana',
#  'Zambia',
#  'Canada',
#  'United Arab Emirates',
#  'Switzerland',
#  'Bahamas',
#  'China',
#  'Botswana',
#  'Germany',
#  'Hong Kong',
#  'Denmark',
#  'Indonesia',
#  'Dominican Republic',
#  'India',
#  'Egypt',
#  'Italy',
#  'Finland',
#  'China',
#  'France',
#  'Turkey',
#  'United Kingdom',
#  'United States',
#  'Swaziland',
#  'South Africa',
#  'Hong Kong',
#  'Bahamas',
#  'India',
#  'China',
#  'Italy',
#  'Germany',
#  'Japan',
#  'Hong Kong',
#  'Mozambique',
#  'India',
#  'Mauritius',
#  'Mozambique',
#  'Namibia',
#  'United Arab Emirates',
#  'Nigeria',
#  'South Africa',
#  'Netherlands',
#  'Zambia',
#  'Norway',
#  'Austria',
#  'Poland',
#  'Belgium',
#  'Portugal',
#  'China',
#  'Thailand',
#  'Germany',
#  'World',
#  'United Kingdom',
#  'South Africa',
#  'Hong Kong',
#  'Zambia',
#  'India',
#  'United States',
#  'China',
#  'South Africa',
#  'South Africa',
#  'China',
#  'China',
#  'Germany',
#  'United States',
#  'France',
#  'South Africa',
#  'United Kingdom',
#  'Belgium',
#  'South Africa',
#  'Switzerland',
#  'China',
#  'Chile',
#  'South Africa',
#  'China',
#  'China',
#  'Germany',
#  'India',
#  'France',
#  'Sri Lanka',
#  'India',
#  'United States',
#  'Israel',
#  'South Africa',
#  'Italy',
#  'Mozambique',
#  'Greece',
#  'Switzerland',
#  'Hong Kong',
#  'China',
#  'Netherlands',
#  'Germany',
#  'Poland',
#  'Denmark',
#  'South Africa',
#  'France',
#  'Austria',
#  'United Kingdom',
#  'China',
#  'Hong Kong',
#  'Hong Kong',
#  'Italy',
#  'United States',
#  'Pakistan',
#  'South Africa',
#  'Poland',
#  'Germany',
#  'United Arab Emirates',
#  'South Africa',
#  'Australia',
#  'China',
#  'Austria',
#  'United Kingdom',
#  'Belgium',
#  'Pakistan',
#  'South Africa',
#  'South Africa',
#  'Zambia',
#  'Switzerland',
#  'Switzerland',
#  'China',
#  'Chile',
#  'Italy',
#  'China',
#  'South Africa',
#  'Germany',
#  'China',
#  'Denmark',
#  'Mozambique',
#  'Finland',
#  'South Africa',
#  'France',
#  'India',
#  'United Kingdom',
#  'South Africa',
#  'Spain',
#  'Zambia',
#  'Greece',
#  'China',
#  'Hong Kong',
#  'Germany',
#  'Israel',
#  'France',
#  'Italy',
#  'United Kingdom',
#  'India',
#  'Hong Kong',
#  'Sri Lanka',
#  'India',
#  'Mozambique',
#  'South Africa',
#  'Mauritius',
#  'Germany',
#  'Pakistan',
#  'India',
#  'Poland',
#  'Norway',
#  'Netherlands',
#  'Botswana',
#  'Turkey',
#  'South Africa',
#  'United States',
#  'South Africa',
#  'World',
#  'China',
#  'South Africa',
#  'South Africa',
#  'Zambia',
#  'China',
#  'United Arab Emirates',
#  'Germany',
#  'Belgium',
#  'Hong Kong',
#  'South Africa',
#  'India',
#  'United Arab Emirates',
#  'Mozambique',
#  'China',
#  'Sweden',
#  'Germany',
#  'South Africa',
#  'Belgium',
#  'Zambia',
#  'United Kingdom',
#  'China',
#  'India',
#  'South Africa',
#  'United States',
#  'Indonesia',
#  'South Africa',
#  'Singapore',
#  'United Kingdom',
#  'United States',
#  'South Africa',
#  'South Africa',
#  'China',
#  'China',
#  'United Arab Emirates',
#  'South Africa',
#  'Denmark',
#  'China',
#  'Spain',
#  'India',
#  'United Kingdom',
#  'Lithuania',
#  'China',
#  'Netherlands',
#  'United States',
#  'Russia',
#  'South Africa',
#  'United States',
#  'United Arab Emirates',
#  'South Africa',
#  'Belgium',
#  'Zambia',
#  'Switzerland',
#  'Germany',
#  'China',
#  'Denmark',
#  'Germany',
#  'France',
#  'Denmark',
#  'United Kingdom',
#  'Hong Kong',
#  'Canada',
#  'Hungary',
#  'Switzerland',
#  'India',
#  'Netherlands',
#  'Ireland',
#  'United States',
#  'France',
#  'South Africa',
#  'United Kingdom',
#  'United Arab Emirates',
#  'Israel',
#  'Argentina',
#  'South Korea',
#  'Belgium',
#  'Lithuania',
#  'Brazil',
#  'Netherlands',
#  'Botswana',
#  'North Korea',
#  'China',
#  'United States',
#  'Germany',
#  'South Africa',
#  'Egypt',
#  'Zambia',
#  'United Kingdom',
#  'Austria',
#  'Greece',
#  'Belgium',
#  'Italy',
#  'Brazil',
#  'Japan',
#  'Botswana',
#  'Kenya',
#  'Switzerland',
#  'South Korea',
#  'China',
#  'Indonesia',
#  'United Arab Emirates',
#  'Sri Lanka',
#  'Argentina',
#  'Mozambique',
#  'Germany',
#  'Mauritius',
#  'Finland',
#  'Malaysia',
#  'France',
#  'Nigeria',
#  'United Kingdom',
#  'Portugal',
#  'Hong Kong',
#  'Senegal',
#  'India',
#  'Singapore',
#  'Israel',
#  'United States',
#  'Italy',
#  'World',
#  'Mozambique',
#  'South Africa',
#  'Netherlands',
#  'Zambia',
#  'New Zealand',
#  'United Arab Emirates',
#  'Pakistan',
#  'Turkey',
#  'Sweden',
#  'Tanzania',
#  'Turkey',
#  'China',
#  'South Africa',
#  'Germany',
#  'Zambia',
#  'United Kingdom',
#  'United States',
#  'Guinea',
#  'South Africa',
#  'Greece',
#  'South Africa',
#  'Ethiopia',
#  'United Arab Emirates',
#  'Kuwait',
#  'China',
#  'Mali',
#  'United Kingdom',
#  'Netherlands',
#  'Greece',
#  'Qatar',
#  'India',
#  'Rwanda',
#  'Namibia',
#  'Sweden',
#  'Netherlands',
#  'Thailand',
#  'Poland',
#  'United States',
#  'Russia',
#  'South Africa',
#  'United States',
#  'Brazil',
#  'World',
#  'China',
#  'South Africa',
#  'Germany',
#  'United Arab Emirates',
#  'Denmark',
#  'China',
#  'United Kingdom',
#  'Denmark',
#  'Hong Kong',
#  'Netherlands',
#  'India',
#  'United States',
#  'Netherlands',
#  'South Africa',
#  'United States',
#  'United Arab Emirates',
#  'South Africa',
#  'Austria',
#  'United Arab Emirates',
#  'Belgium',
#  'China',
#  'Canada',
#  'Germany',
#  'Switzerland',
#  'Spain',
#  'China',
#  'France',
#  'Germany',
#  'Hong Kong',
#  'Denmark',
#  'India',
#  'United Kingdom',
#  'United States',
#  'Hong Kong',
#  'South Africa',
#  'India',
#  'Zambia',
#  'Ireland',
#  'Belgium',
#  'Mozambique',
#  'China',
#  'Namibia',
#  'South Africa',
#  'Netherlands',
#  'Albania',
#  'Oman',
#  'United Arab Emirates',
#  'Pakistan',
#  'Austria',
#  'Qatar',
#  'Belgium',
#  'Sweden',
#  'Botswana',
#  'Turkey',
#  'Canada',
#  'United States',
#  'Switzerland',
#  'South Africa',
#  'China',
#  'Albania',
#  'Germany',
#  'United Arab Emirates',
#  'Denmark',
#  'Austria',
#  'Egypt',
#  'Belgium',
#  'Ethiopia',
#  'Brazil',
#  'France',
#  'Botswana',
#  'United Kingdom',
#  'Canada',
#  'Hong Kong',
#  'Switzerland',
#  'Indonesia',
#  'China',
#  'India',
#  'Cyprus',
#  'Ireland',
#  'Germany',
#  'Italy',
#  'Denmark',
#  'Netherlands',
#  'Egypt',
#  'Pakistan',
#  'France',
#  'Thailand',
#  'United Kingdom',
#  'United States',
#  'Hong Kong',
#  'South Africa',
#  'Indonesia',
#  'China',
#  'India',
#  'Hong Kong',
#  'Iceland',
#  'Lesotho',
#  'Israel',
#  'Afghanistan',
#  'Italy',
#  'Australia',
#  'South Korea',
#  'Austria',
#  'Sri Lanka',
#  'Belgium',
#  'Mozambique',
#  'Bahrain',
#  'Namibia',
#  'Brazil',
#  'Nigeria',
#  'Botswana',
#  'Netherlands',
#  'Canada',
#  'Pakistan',
#  'Switzerland',
#  'Poland',
#  'United Arab Emirates',
#  'Qatar',
#  'China',
#  'Seychelles',
#  'Cyprus',
#  'Thailand',
#  'Germany',
#  'Turkey',
#  'Denmark',
#  'Tanzania',
#  'Egypt',
#  'Ukraine',
#  'Spain',
#  'United States',
#  'Ethiopia',
#  'South Africa',
#  'France',
#  'Zambia',
#  'United Kingdom',
#  'Aruba',
#  'Ghana',
#  'United Arab Emirates',
#  'Hong Kong',
#  'Austria',
#  'Hungary',
#  'Botswana',
#  'Indonesia',
#  'Canada',
#  'India',
#  'China',
#  'Ireland',
#  'Egypt',
#  'Israel',
#  'Spain',
#  'Italy',
#  'France',
#  'Japan',
#  'United Kingdom',
#  'Kenya',
#  'Ghana',
#  'Cambodia',
#  'Germany',
#  'Iraq',
#  'Hong Kong',
#  'South Korea',
#  'India',
#  'Lesotho',
#  'Italy',
#  'Lithuania',
#  'St Kitts and Nevis',
#  'Morocco',
#  'Mozambique',
#  'Mauritius',
#  'Namibia',
#  'Malawi',
#  'Nigeria',
#  'Malaysia',
#  'Netherlands',
#  'Namibia',
#  'New Zealand',
#  'Nigeria',
#  'Kuwait',
#  'Mozambique',
#  'Peru',
#  'Netherlands',
#  'Poland',
#  'New Zealand',
#  'Qatar',
#  'Oman',
#  'Saudi Arabia',
#  'Pakistan',
#  'Seychelles',
#  'Philippines',
#  'Tanzania',
#  'Poland',
#  'United States',
#  'North Korea',
#  'South Africa',
#  'Qatar',
#  'Zambia',
#  'Rwanda',
#  'United Arab Emirates',
#  'Saudi Arabia',
#  'Switzerland',
#  'Sweden',
#  'China',
#  'Swaziland',
#  'Spain',
#  'Thailand',
#  'Finland',
#  'Turkey',
#  'France',
#  'Tanzania',
#  'United Kingdom',
#  'Uganda',
#  'Germany',
#  'Ukraine',
#  'Denmark',
#  'United States',
#  'Hong Kong',
#  'World',
#  'Italy',
#  'South Africa',
#  'Mozambique',
#  'Zambia',
#  'Saudi Arabia',
#  'Afghanistan',
#  'Singapore',
#  'United Arab Emirates',
#  'Slovakia',
#  'Australia',
#  'Sweden',
#  'Austria',
#  'Swaziland',
#  'Belgium',
#  'Seychelles',
#  'Botswana',
#  'Turkey',
#  'Canada',
#  'Tanzania',
#  'Switzerland',
#  'Uganda',
#  'China',
#  'Thailand',
#  'Bahrain',
#  'United States',
#  'Germany',
#  'World',
#  'Denmark',
#  'South Africa',
#  'Egypt',
#  'Zambia',
#  'Spain',
#  'United Arab Emirates',
#  'Ethiopia',
#  'Austria',
#  'United Kingdom',
#  'Bahamas',
#  'Ghana',
#  'Brazil',
#  'Greece',
#  'Botswana',
#  'Hong Kong',
#  'Canada',
#  'France',
#  'Switzerland',
#  'Hungary',
#  'China',
#  'India',
#  'Germany',
#  'Ireland',
#  'Denmark',
#  'Italy',
#  'Egypt',
#  'Japan',
#  'Spain',
#  'Kenya',
#  'France',
#  'Cambodia',
#  'United Kingdom',
#  'Kuwait',
#  'Hong Kong',
#  'Sri Lanka',
#  'Indonesia',
#  'Lesotho',
#  'India',
#  'Lithuania',
#  'Ireland',
#  'Mali',
#  'Italy',
#  'Mozambique',
#  'South Korea',
#  'Mauritius',
#  'Mozambique',
#  'Malaysia',
#  'Netherlands',
#  'Namibia',
#  'Poland',
#  'Nigeria',
#  'Portugal',
#  'Netherlands',
#  'Singapore',
#  'New Zealand',
#  'Slovakia',
#  'Pakistan',
#  'Sweden',
#  'Poland',
#  'Turkey',
#  'North Korea',
#  'United States',
#  'Portugal',
#  'South Africa',
#  'Qatar',
#  'Zambia',
#  'Russia',
#  'United Arab Emirates',
#  'Saudi Arabia',
#  'China',
#  'Singapore',
#  'Germany',
#  'Swaziland',
#  'Ireland',
#  'Thailand',
#  'Italy',
#  'Turkey',
#  'United Kingdom',
#  'Tanzania',
#  'Hong Kong',
#  'Uganda',
#  'United States',
#  'World',
#  'South Africa',
#  'South Africa',
#  'China',
#  'Zambia',
#  'Germany',
#  'United States',
#  'Netherlands',
#  'Botswana',
#  'South Africa',
#  'China',
#  'United Arab Emirates',
#  'India',
#  'Austria',
#  'Mozambique',
#  'Belgium',
#  'South Africa',
#  'Botswana',
#  'China',
#  'China',
#  'United Kingdom',
#  'Cyprus',
#  'South Africa',
#  'Germany',
#  'Zambia',
#  'Denmark',
#  'China',
#  'United Kingdom',
#  'Botswana',
#  'Hong Kong',
#  'United Kingdom',
#  'India',
#  'South Africa',
#  'Japan',
#  'Zambia',
#  'Kenya',
#  'United Arab Emirates',
#  'Cambodia',
#  'Switzerland',
#  'Mauritius',
#  'China',
#  'United States',
#  'Germany',
#  'World',
#  'Denmark',
#  'South Africa',
#  'Hong Kong',
#  'United Arab Emirates',
#  'United States',
#  'Botswana',
#  'South Africa',
#  'United Kingdom',
#  'United Arab Emirates',
#  'United States',
#  'China',
#  'South Africa',
#  'United Kingdom',
#  'China',
#  'Hong Kong',
#  'United States',
#  'Afghanistan',
#  'China',
#  'United Arab Emirates',
#  'India',
#  'Australia',
#  'South Africa',
#  'Austria',
#  'South Africa',
#  'Belgium',
#  'United Arab Emirates',
#  'Bahamas',
#  'China',
#  'Brazil',
#  'Germany',
#  'Botswana',
#  'Hong Kong',
#  'Canada',
#  'South Africa',
#  'Switzerland',
#  'United Arab Emirates',
#  'China',
#  'Austria',
#  'Cameroon',
#  'Belgium',
#  'Republic of the Congo',
#  'Bangladesh',
#  'Czech Republic',
#  'Botswana',
#  'Germany',
#  'Switzerland',
#  'Denmark',
#  'China',
#  ...]

# %%
text = " ".join(i for i in import_countries)
wordcloud = WordCloud(background_color="white").generate(text)
plt.figure( figsize=(15,15))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# exports
export_partners = trading_partners.loc[trading_partners['type'] == 'Export']
export_partners
# Out:
#            symbol  country1       country2    type  \
# 0     ZWEAGO00002  Zimbabwe         Angola  Export
# 1     ZWEUSA01062  Zimbabwe  United States  Export
# 2     ZWEAUS00002  Zimbabwe      Australia  Export
# 3     ZWEZMB01062  Zimbabwe         Zambia  Export
# 4     ZWEAUT00002  Zimbabwe        Austria  Export
# ...           ...       ...            ...     ...
# 2246  ZWEZMB72172  Zimbabwe         Zambia  Export
# 2248  ZWEZAF83112  Zimbabwe   South Africa  Export
# 2250  ZWEMOZ62062  Zimbabwe     Mozambique  Export
# 2252  ZWEZAF62062  Zimbabwe   South Africa  Export
# 2254  ZWEZAF61022  Zimbabwe   South Africa  Export
#
#                                                category  \
# 0                                                  None
# 1                Animals, live, not specified elsewhere
# 2                                                  None
# 3                Animals, live, not specified elsewhere
# 4                                                  None
# ...                                                 ...
# 2246                    Wire of Iron or Non-alloy Steel
# 2248  Wire, Rods, Tubes, Plates, Electrodes, of Base...
# 2250  Women's or girls' blouses, shirts, not knitted...
# 2252  Women's or girls' blouses, shirts, not knitted...
# 2254  Women's or Girls' Overcoats, Carcoats, Knitted...
#
#                                                     url  \
# 0                              /zimbabwe/exports/angola
# 1     /zimbabwe/exports/united-states/other-live-ani...
# 2                           /zimbabwe/exports/australia
# 3           /zimbabwe/exports/zambia/other-live-animals
# 4                             /zimbabwe/exports/austria
# ...                                                 ...
# 2246  /zimbabwe/exports/zambia/wire-iron-non-alloy-s...
# 2248  /zimbabwe/exports/south-africa/wire-rods-solde...
# 2250  /zimbabwe/exports/mozambique/womens-girls-blou...
# 2252  /zimbabwe/exports/south-africa/womens-girls-bl...
# 2254  /zimbabwe/exports/south-africa/womens-girls-ov...
#
#                                                   title           lastupdate
# 0                            Zimbabwe exports to Angola  2021-03-30T00:38:00
# 1     Zimbabwe exports of animals, live, not specifi...  2021-03-26T22:10:00
# 2                         Zimbabwe exports to Australia  2021-03-30T00:38:00
# 3     Zimbabwe exports of animals, live, not specifi...  2021-03-26T22:10:00
# 4                           Zimbabwe exports to Austria  2021-03-30T00:38:00
# ...                                                 ...                  ...
# 2246  Zimbabwe exports of wire of iron or non-alloy ...  2021-03-26T22:10:00
# 2248  Zimbabwe exports of wire, rods, tubes, plates,...  2021-03-26T22:07:00
# 2250  Zimbabwe exports of women's or girls' blouses,...  2021-03-26T21:42:00
# 2252  Zimbabwe exports of women's or girls' blouses,...  2021-03-26T22:07:00
# 2254  Zimbabwe exports of women's or girls' overcoat...  2021-03-26T22:07:00
#
# [2241 rows x 8 columns]

# %%
export_countries = export_partners['country2'].tolist()
export_countries
# Out:
# ['Angola',
#  'United States',
#  'Australia',
#  'Zambia',
#  'Austria',
#  'Botswana',
#  'United Arab Emirates',
#  'Mozambique',
#  'Argentina',
#  'Nigeria',
#  'Belgium',
#  'South Africa',
#  'Burkina Faso',
#  'Zambia',
#  'Brazil',
#  'Mozambique',
#  'Barbados',
#  'World',
#  'Botswana',
#  'South Africa',
#  'Canada',
#  'United Kingdom',
#  'Switzerland',
#  'Libya',
#  'China',
#  'Mozambique',
#  'Congo',
#  'South Africa',
#  'Republic of the Congo',
#  'Botswana',
#  'Comoros',
#  'Republic of the Congo',
#  'Cyprus',
#  'China',
#  'Czech Republic',
#  'Mozambique',
#  'Germany',
#  'Namibia',
#  'Denmark',
#  'Portugal',
#  'Egypt',
#  'South Africa',
#  'Spain',
#  'Zambia',
#  'Ethiopia',
#  'Mozambique',
#  'United Kingdom',
#  'United States',
#  'Georgia',
#  'South Africa',
#  'Ghana',
#  'South Africa',
#  'Guinea',
#  'South Africa',
#  'France',
#  'Zambia',
#  'Greece',
#  'China',
#  'Hong Kong',
#  'Zambia',
#  'Hungary',
#  'Australia',
#  'Indonesia',
#  'Botswana',
#  'India',
#  'United Kingdom',
#  'Ireland',
#  'Mozambique',
#  'Iran',
#  'Malawi',
#  'Iraq',
#  'United States',
#  'Israel',
#  'World',
#  'Italy',
#  'South Africa',
#  'Jordan',
#  'Zambia',
#  'Japan',
#  'United Arab Emirates',
#  'South Korea',
#  'Belgium',
#  'Kuwait',
#  'Burkina Faso',
#  'Laos',
#  'Botswana',
#  'Lebanon',
#  'Germany',
#  'Libya',
#  'United Kingdom',
#  'Sri Lanka',
#  'Georgia',
#  'Lesotho',
#  'Iraq',
#  'Kenya',
#  'Jordan',
#  'Luxembourg',
#  'Kenya',
#  'Moldova',
#  'Lebanon',
#  'Madagascar',
#  'Libya',
#  'Mexico',
#  'Mozambique',
#  'Mozambique',
#  'Malawi',
#  'Mauritius',
#  'Sudan',
#  'Malawi',
#  'Senegal',
#  'Malaysia',
#  'Somalia',
#  'Namibia',
#  'Ukraine',
#  'Nigeria',
#  'World',
#  'Netherlands',
#  'South Africa',
#  'Norway',
#  'Zambia',
#  'New Zealand',
#  'Botswana',
#  'Romania',
#  'United Kingdom',
#  'Russia',
#  'Mozambique',
#  'Rwanda',
#  'South Africa',
#  'Saudi Arabia',
#  'Zambia',
#  'Sudan',
#  'Botswana',
#  'Senegal',
#  'Mozambique',
#  'Singapore',
#  'Zambia',
#  'Poland',
#  'United Kingdom',
#  'North Korea',
#  'South Africa',
#  'Portugal',
#  'Zambia',
#  'Somalia',
#  'United Kingdom',
#  'Sweden',
#  'United States',
#  'Swaziland',
#  'South Africa',
#  'Seychelles',
#  'Zambia',
#  'Turkey',
#  'Botswana',
#  'Tanzania',
#  'China',
#  'Uganda',
#  'United Kingdom',
#  'Ukraine',
#  'Kenya',
#  'United States',
#  'Mozambique',
#  'Vietnam',
#  'Malawi',
#  'World',
#  'Nigeria',
#  'South Africa',
#  'United States',
#  'Zambia',
#  'South Africa',
#  'Thailand',
#  'Zambia',
#  'Zambia',
#  'United Arab Emirates',
#  'Mozambique',
#  'Spain',
#  'Botswana',
#  'France',
#  'Mozambique',
#  'United Kingdom',
#  'Namibia',
#  'China',
#  'South Africa',
#  'Ireland',
#  'Zambia',
#  'Mozambique',
#  'Mozambique',
#  'New Zealand',
#  'Botswana',
#  'United States',
#  'Mozambique',
#  'South Africa',
#  'South Africa',
#  'Botswana',
#  'Zambia',
#  'South Africa',
#  'Egypt',
#  'Zambia',
#  'Sudan',
#  'Mozambique',
#  'South Africa',
#  'South Africa',
#  'Australia',
#  'Zambia',
#  'Botswana',
#  'South Africa',
#  'Canada',
#  'Botswana',
#  'Czech Republic',
#  'Mozambique',
#  'Egypt',
#  'Zambia',
#  'Malaysia',
#  'United Arab Emirates',
#  'United States',
#  'Botswana',
#  'World',
#  'China',
#  'South Africa',
#  'Mozambique',
#  'Sudan',
#  'Malawi',
#  'Botswana',
#  'World',
#  'Sudan',
#  'South Africa',
#  'World',
#  'Zambia',
#  'South Africa',
#  'Mozambique',
#  'Zambia',
#  'World',
#  'Botswana',
#  'South Africa',
#  'South Africa',
#  'Botswana',
#  'Zambia',
#  'Mozambique',
#  'Botswana',
#  'Botswana',
#  'China',
#  'South Africa',
#  'Malawi',
#  'Botswana',
#  'World',
#  'Zambia',
#  'South Africa',
#  'South Africa',
#  'Zambia',
#  'Tanzania',
#  'South Africa',
#  'Zambia',
#  'Zambia',
#  'South Africa',
#  'China',
#  'Zambia',
#  'South Africa',
#  'Mozambique',
#  'Mozambique',
#  'South Africa',
#  'Botswana',
#  'Zambia',
#  'Mozambique',
#  'Botswana',
#  'Botswana',
#  'Botswana',
#  'France',
#  'Mozambique',
#  'United Kingdom',
#  'South Africa',
#  'Mozambique',
#  'Zambia',
#  'Germany',
#  'Namibia',
#  'World',
#  'Botswana',
#  'South Africa',
#  'Mozambique',
#  'Zambia',
#  'South Africa',
#  'Kuwait',
#  'Zambia',
#  'World',
#  'Mozambique',
#  'South Africa',
#  'Botswana',
#  'Zambia',
#  'Zambia',
#  'Botswana',
#  'Botswana',
#  'United Kingdom',
#  'Mozambique',
#  'Mozambique',
#  'South Africa',
#  'United States',
#  'Zambia',
#  'South Africa',
#  'Botswana',
#  'Zambia',
#  'United Arab Emirates',
#  'United Arab Emirates',
#  'Argentina',
#  'Botswana',
#  'Austria',
#  'Canada',
#  'Canada',
#  'United Kingdom',
#  'Switzerland',
#  'Swaziland',
#  'Germany',
#  'United States',
#  'Spain',
#  'South Africa',
#  'United Kingdom',
#  'Zambia',
#  'Italy',
#  'Mozambique',
#  'Mozambique',
#  'South Africa',
#  'Norway',
#  'United Arab Emirates',
#  'New Zealand',
#  'Botswana',
#  'Sweden',
#  'Mauritius',
#  'United States',
#  'World',
#  'South Africa',
#  'South Africa',
#  'Australia',
#  'Zambia',
#  'World',
#  'Botswana',
#  'South Africa',
#  'Zambia',
#  'Zambia',
#  'South Africa',
#  'South Africa',
#  'Zambia',
#  'Zambia',
#  'India',
#  'Botswana',
#  'South Africa',
#  'Mozambique',
#  'Germany',
#  'South Africa',
#  'Botswana',
#  'Zambia',
#  'Hungary',
#  'South Africa',
#  'Italy',
#  'South Africa',
#  'Mozambique',
#  'Botswana',
#  'United States',
#  'United Kingdom',
#  'South Africa',
#  'Mozambique',
#  'Zambia',
#  'World',
#  'Argentina',
#  'South Africa',
#  'South Africa',
#  'Zambia',
#  'China',
#  'Mozambique',
#  'South Africa',
#  'Mozambique',
#  'United States',
#  'Botswana',
#  'South Africa',
#  'Mozambique',
#  'South Africa',
#  'Namibia',
#  'Botswana',
#  'South Africa',
#  'Botswana',
#  'Zambia',
#  'South Africa',
#  'Tanzania',
#  'Zambia',
#  'World',
#  'Zambia',
#  'South Africa',
#  'South Africa',
#  'Zambia',
#  'Mozambique',
#  'South Africa',
#  'Botswana',
#  'South Africa',
#  'Botswana',
#  'Zambia',
#  'Mozambique',
#  'South Africa',
#  'South Africa',
#  'Zambia',
#  'Zambia',
#  'South Africa',
#  'Zambia',
#  'Brazil',
#  'Zambia',
#  'Germany',
#  'South Africa',
#  'Denmark',
#  'Zambia',
#  'United Kingdom',
#  'Botswana',
#  'Netherlands',
#  'Mozambique',
#  'Norway',
#  'World',
#  'Saudi Arabia',
#  'South Africa',
#  'South Africa',
#  'Zambia',
#  'Botswana',
#  'Botswana',
#  'Mozambique',
#  'Zambia',
#  'Malawi',
#  'Mozambique',
#  'World',
#  'South Africa',
#  'South Africa',
#  'Mozambique',
#  'Zambia',
#  'Botswana',
#  'Netherlands',
#  'Germany',
#  'South Africa',
#  'Mozambique',
#  'South Africa',
#  'South Africa',
#  'Zambia',
#  'Zambia',
#  'United Arab Emirates',
#  'South Africa',
#  'Belgium',
#  'Botswana',
#  'United States',
#  'Mozambique',
#  'Mozambique',
#  'Sudan',
#  'South Africa',
#  'South Africa',
#  'Zambia',
#  'Mozambique',
#  'South Africa',
#  'Botswana',
#  'Zambia',
#  'South Africa',
#  'South Africa',
#  'Zambia',
#  'South Africa',
#  'Botswana',
#  'Zambia',
#  'Mozambique',
#  'Botswana',
#  'Mozambique',
#  'Canada',
#  'Malawi',
#  'Germany',
#  'World',
#  'United Kingdom',
#  'South Africa',
#  'Hong Kong',
#  'Zambia',
#  'Japan',
#  'Mozambique',
#  'Kenya',
#  'South Africa',
#  'Mozambique',
#  'South Africa',
#  'Malaysia',
#  'Botswana',
#  'Netherlands',
#  'China',
#  'Romania',
#  'France',
#  'World',
#  'Mozambique',
#  'South Africa',
#  'Malawi',
#  'Zambia',
#  'Namibia',
#  'Mozambique',
#  'Netherlands',
#  'United States',
#  'World',
#  'Botswana',
#  'South Africa',
#  'France',
#  'Zambia',
#  'United Kingdom',
#  'Botswana',
#  'Germany',
#  'Mozambique',
#  'Egypt',
#  'Malawi',
#  'Ireland',
#  'Namibia',
#  'Kenya',
#  'Kenya',
#  'Mozambique',
#  'Tanzania',
#  'Netherlands',
#  'World',
#  'World',
#  'South Africa',
#  'South Africa',
#  'Zambia',
#  'Zambia',
#  'Botswana',
#  'Mozambique',
#  'South Africa',
#  'South Africa',
#  'Zambia',
#  'Zambia',
#  'South Africa',
#  'South Africa',
#  'Botswana',
#  'Botswana',
#  'Zambia',
#  'Mozambique',
#  'South Africa',
#  'South Africa',
#  'Botswana',
#  'Zambia',
#  'Mozambique',
#  'Botswana',
#  'United Arab Emirates',
#  'China',
#  'Switzerland',
#  'Mozambique',
#  'Zambia',
#  'South Africa',
#  'China',
#  'Zambia',
#  'Cyprus',
#  'United Kingdom',
#  'Mozambique',
#  'Italy',
#  'Saudi Arabia',
#  'South Africa',
#  'South Africa',
#  'Zambia',
#  'United Arab Emirates',
#  'Mozambique',
#  'Botswana',
#  'Malawi',
#  'Zambia',
#  'Rwanda',
#  'France',
#  'World',
#  'Mozambique',
#  'South Africa',
#  'United States',
#  'Zambia',
#  'South Africa',
#  'Mozambique',
#  'Zambia',
#  'Zambia',
#  'South Africa',
#  'South Africa',
#  'Zambia',
#  'Germany',
#  'Botswana',
#  'United Kingdom',
#  'Mozambique',
#  'Romania',
#  'South Africa',
#  'United States',
#  'World',
#  'South Africa',
#  'South Africa',
#  'Botswana',
#  'South Africa',
#  'Mozambique',
#  'Zambia',
#  'South Africa',
#  'Mozambique',
#  'Zambia',
#  'South Africa',
#  'Sudan',
#  'United Arab Emirates',
#  'Netherlands',
#  'Switzerland',
#  'South Africa',
#  'World',
#  'South Africa',
#  'South Africa',
#  'Mozambique',
#  'Zambia',
#  'United Arab Emirates',
#  'South Africa',
#  'Belgium',
#  'United Kingdom',
#  'Botswana',
#  'Mozambique',
#  'France',
#  'South Africa',
#  'Mozambique',
#  'United Arab Emirates',
#  'Malawi',
#  'Denmark',
#  'World',
#  'United Kingdom',
#  'South Africa',
#  'India',
#  'Zambia',
#  'Kenya',
#  'World',
#  'Mozambique',
#  'South Africa',
#  'Malaysia',
#  'Mozambique',
#  'Russia',
#  'Botswana',
#  'Saudi Arabia',
#  'Zambia',
#  'World',
#  'United Kingdom',
#  'South Africa',
#  'Mozambique',
#  'Zambia',
#  'South Africa',
#  'Mozambique',
#  'Zambia',
#  'South Africa',
#  'Botswana',
#  'Sudan',
#  'Mozambique',
#  'South Africa',
#  'Malawi',
#  'Namibia',
#  'World',
#  'Zambia',
#  'South Africa',
#  'United States',
#  'Zambia',
#  'South Africa',
#  'Mozambique',
#  'United Kingdom',
#  'Zambia',
#  'Mozambique',
#  'Botswana',
#  'South Africa',
#  'South Africa',
#  'Zambia',
#  'Zambia',
#  'United Arab Emirates',
#  'Botswana',
#  'Mozambique',
#  'Mozambique',
#  'South Africa',
#  'South Africa',
#  'United Arab Emirates',
#  'Mozambique',
#  'Botswana',
#  'Tanzania',
#  'China',
#  'South Africa',
#  'Republic of the Congo',
#  'Zambia',
#  'Hong Kong',
#  'Botswana',
#  'United Kingdom',
#  'Mozambique',
#  'Italy',
#  'South Africa',
#  'Madagascar',
#  'Zambia',
#  'Mozambique',
#  'South Africa',
#  'Malawi',
#  'Mozambique',
#  'Malaysia',
#  'South Africa',
#  'North Korea',
#  'Mozambique',
#  'Sudan',
#  'World',
#  'Seychelles',
#  'South Africa',
#  'Tanzania',
#  'South Africa',
#  'United States',
#  'South Africa',
#  'World',
#  'Mozambique',
#  'South Africa',
#  'Nigeria',
#  'Zambia',
#  'United States',
#  'United States',
#  'South Africa',
#  'South Africa',
#  'Germany',
#  'Mozambique',
#  'France',
#  'Mozambique',
#  'United Kingdom',
#  'South Africa',
#  'Ireland',
#  'Zambia',
#  'Netherlands',
#  'South Africa',
#  'South Africa',
#  'Nigeria',
#  'Zambia',
#  'South Africa',
#  'South Africa',
#  'Zambia',
#  'Zambia',
#  'United Arab Emirates',
#  'Greece',
#  'Australia',
#  'South Africa',
#  'Botswana',
#  'South Africa',
#  'Japan',
#  'Botswana',
#  'Mozambique',
#  'Kuwait',
#  'Russia',
#  'Mozambique',
#  'United States',
#  'Malawi',
#  'World',
#  'United States',
#  'South Africa',
#  'World',
#  'Zambia',
#  'South Africa',
#  'Mozambique',
#  'Zambia',
#  'Russia',
#  'Mozambique',
#  'United States',
#  'South Africa',
#  'South Africa',
#  'Zambia',
#  'Botswana',
#  'Brazil',
#  'Canada',
#  'Germany',
#  'Switzerland',
#  'Denmark',
#  'China',
#  'United Kingdom',
#  'Mozambique',
#  'Japan',
#  'Swaziland',
#  'Mozambique',
#  'United States',
#  'Netherlands',
#  'South Africa',
#  'Norway',
#  'Zambia',
#  'Saudi Arabia',
#  'United Arab Emirates',
#  'World',
#  'Mozambique',
#  'South Africa',
#  'South Africa',
#  'Zambia',
#  'Zambia',
#  'South Africa',
#  'Botswana',
#  'South Africa',
#  'Mozambique',
#  'Zambia',
#  'South Africa',
#  'Mozambique',
#  'Zambia',
#  'South Africa',
#  'World',
#  'Mozambique',
#  'South Africa',
#  'South Africa',
#  'Zambia',
#  'South Africa',
#  'Zambia',
#  'South Africa',
#  'South Africa',
#  'Zambia',
#  'Mozambique',
#  'Zambia',
#  'United States',
#  'South Africa',
#  'China',
#  'Mozambique',
#  'Mozambique',
#  'South Africa',
#  'South Africa',
#  'South Africa',
#  'Zambia',
#  'Zambia',
#  'Mozambique',
#  'Botswana',
#  'Saudi Arabia',
#  'Mozambique',
#  'South Africa',
#  'South Africa',
#  'Zambia',
#  'Zambia',
#  'Botswana',
#  'Sudan',
#  'Zambia',
#  'Tanzania',
#  'South Africa',
#  'South Africa',
#  'Zambia',
#  'Mozambique',
#  'Botswana',
#  'China',
#  'Mozambique',
#  'Mozambique',
#  'World',
#  'South Africa',
#  'Zambia',
#  'South Africa',
#  'Mozambique',
#  'United Arab Emirates',
#  'South Africa',
#  'Botswana',
#  'Zambia',
#  'Canada',
#  'South Africa',
#  'China',
#  'Botswana',
#  'Germany',
#  'Mozambique',
#  'United Kingdom',
#  'South Africa',
#  'Hungary',
#  'Zambia',
#  'Ireland',
#  'France',
#  'Italy',
#  'Zambia',
#  'Mexico',
#  'Botswana',
#  'Mozambique',
#  'France',
#  'Mauritius',
#  'Malawi',
#  'Malawi',
#  'World',
#  'Malaysia',
#  'South Africa',
#  'Namibia',
#  'Zambia',
#  'Nigeria',
#  'Botswana',
#  'Netherlands',
#  'South Africa',
#  'Kenya',
#  'Zambia',
#  'Sudan',
#  'Zambia',
#  'Thailand',
#  'Botswana',
#  'Tanzania',
#  'Germany',
#  'United States',
#  'France',
#  'World',
#  'United Kingdom',
#  'South Africa',
#  'South Africa',
#  'Zambia',
#  'Zambia',
#  'Botswana',
#  'Mozambique',
#  'Mozambique',
#  'South Africa',
#  'South Africa',
#  'Mozambique',
#  'Zambia',
#  'Zambia',
#  'South Africa',
#  'South Africa',
#  'Zambia',
#  'Zambia',
#  'United Arab Emirates',
#  'Mozambique',
#  'Botswana',
#  'Zambia',
#  'South Africa',
#  'South Africa',
#  'Israel',
#  'Ethiopia',
#  'South Africa',
#  'Guinea',
#  'Zambia',
#  'Mozambique',
#  'Mozambique',
#  'Russia',
#  'Libya',
#  'South Africa',
#  'Mozambique',
#  'Zambia',
#  'Somalia',
#  'Botswana',
#  'South Africa',
#  'Mozambique',
#  'Zambia',
#  'Rwanda',
#  'Zambia',
#  'South Africa',
#  'Mozambique',
#  'Zambia',
#  'Tanzania',
#  'Botswana',
#  'South Africa',
#  'Mozambique',
#  'Zambia',
#  'Zambia',
#  'Mozambique',
#  'Botswana',
#  'South Africa',
#  'Botswana',
#  'South Africa',
#  'South Africa',
#  'World',
#  'Zambia',
#  'South Africa',
#  'South Africa',
#  'World',
#  'Zambia',
#  'South Africa',
#  'Mozambique',
#  'Zambia',
#  'United Arab Emirates',
#  'United Arab Emirates',
#  'China',
#  'Botswana',
#  'Hong Kong',
#  'China',
#  'Mozambique',
#  'Spain',
#  'Uganda',
#  'France',
#  'Ukraine',
#  'United Kingdom',
#  'South Africa',
#  'Ireland',
#  'Botswana',
#  'Japan',
#  'Namibia',
#  'Mozambique',
#  'Mozambique',
#  'New Zealand',
#  'Saudi Arabia',
#  'United States',
#  'South Africa',
#  'World',
#  'Zambia',
#  'South Africa',
#  'South Africa',
#  'Zambia',
#  'Mozambique',
#  'Botswana',
#  'South Africa',
#  'Botswana',
#  'Zambia',
#  'Mozambique',
#  'South Africa',
#  'South Africa',
#  'Botswana',
#  'Zambia',
#  'Mozambique',
#  'United Arab Emirates',
#  'South Africa',
#  'Zambia',
#  'Zambia',
#  'Belgium',
#  'Botswana',
#  'Ireland',
#  'South Africa',
#  'World',
#  'Botswana',
#  'South Africa',
#  'South Africa',
#  'Mozambique',
#  'Botswana',
#  'Belgium',
#  'Zambia',
#  'Ireland',
#  'Mozambique',
#  'South Africa',
#  'South Africa',
#  'Mozambique',
#  'Zambia',
#  'Mozambique',
#  'Botswana',
#  'Mozambique',
#  'China',
#  'World',
#  'Mozambique',
#  'South Africa',
#  ...]

# %%
text = " ".join(i for i in export_countries)
wordcloud = WordCloud(background_color="white").generate(text)
plt.figure( figsize=(15,15))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
