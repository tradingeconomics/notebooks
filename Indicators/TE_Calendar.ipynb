# %% [markdown]
# Importing dependencies

# %%
import tradingeconomics as te

# %%
te.login('jupyter:jupyter') # Signup for a free API key at https://developer.tradingeconomics.com/
# Out:
# 'You are logged in as a jupyter:jupyter'

# %% [markdown]
# Importing data

# %%
df = te.getCalendarData(output_type='df')

# %% [markdown]
# Data manipulation

# %%
df['Hour'] = df['Date'].apply(lambda x: x[11:])
df['Date'] = df['Date'].apply(lambda x: x[:10])

df = df[['Date', 'Hour', 'Country', 'Category', 'Event', 'Source', 'Actual', 'Previous', 'Forecast', ]]

df.sort_values(['Date', 'Hour'], inplace=True)

df.head(30)
# Out:
#           Date      Hour      Country               Category  \
# 0   2021-06-26  00:00:00   Madagascar               Holidays
# 1   2021-06-26  00:00:00       Sweden               Holidays
# 2   2021-06-27  00:00:00       France               Calendar
# 3   2021-06-27  01:30:00        China      Corporate Profits
# 4   2021-06-27  23:50:00        Japan          Interest Rate
# 5   2021-06-28  00:00:00   Azerbaijan               Holidays
# 6   2021-06-28  00:00:00        Chile               Holidays
# 7   2021-06-28  00:00:00    Guatemala               Holidays
# 8   2021-06-28  02:00:00   East Timor         Inflation Rate
# 9   2021-06-28  02:00:00  Philippines       Retail Sales Yoy
# 10  2021-06-28  04:00:00     Malaysia                Exports
# 11  2021-06-28  04:00:00     Malaysia                Imports
# 12  2021-06-28  04:00:00     Malaysia       Balance of Trade
# 13  2021-06-28  04:00:00     Thailand  Industrial Production
# 14  2021-06-28  05:00:00      Finland    Consumer Confidence
# 15  2021-06-28  06:00:00      Germany          Import Prices
# 16  2021-06-28  06:00:00      Germany          Import Prices
# 17  2021-06-28  06:00:00    Lithuania       Retail Sales MoM
# 18  2021-06-28  06:00:00    Lithuania       Retail Sales YoY
# 19  2021-06-28  06:00:00       Norway       Retail Sales MoM
# 20  2021-06-28  06:00:00       Norway       Retail Sales YoY
# 21  2021-06-28  06:00:00       Norway     Household Spending
# 22  2021-06-28  07:30:00       Sweden       Retail Sales YoY
# 23  2021-06-28  07:30:00       Sweden       Retail Sales MoM
# 24  2021-06-28  07:30:00       Sweden            Loan Growth
# 25  2021-06-28  08:00:00      Austria      Manufacturing PMI
# 26  2021-06-28  08:00:00   Uzbekistan        Current Account
# 27  2021-06-28  08:00:00   Uzbekistan          External Debt
# 28  2021-06-28  08:10:00    Euro Area          Interest Rate
# 29  2021-06-28  08:30:00    Hong Kong       Balance of Trade
#
#                                   Event  \
# 0                      Independence Day
# 1                         Midsummer Day
# 2        Regional Elections - 2nd Round
# 3          Industrial Profits (YTD) YoY
# 4               BoJ Summary of Opinions
# 5           Azerbijian Armed Forces Day
# 6   Feast of Saint Peter and Saint Paul
# 7                              Army Day
# 8                    Inflation Rate YoY
# 9                Retail Price Index YoY
# 10                          Exports YoY
# 11                          Imports YoY
# 12                     Balance of Trade
# 13            Industrial Production YoY
# 14                  Consumer Confidence
# 15                    Import Prices MoM
# 16                    Import Prices YoY
# 17                     Retail Sales MoM
# 18                     Retail Sales YoY
# 19                     Retail Sales MoM
# 20                     Retail Sales YoY
# 21            Household Consumption MoM
# 22                     Retail Sales YoY
# 23                     Retail Sales MoM
# 24         Household Lending Growth YoY
# 25       Bank Austria Manufacturing PMI
# 26                      Current Account
# 27                        External Debt
# 28                   ECB Panetta Speech
# 29                     Balance of Trade
#
#                                          Source Actual  Previous Forecast
# 0
# 1
# 2
# 3        National Bureau of Statistics of China           106.1%
# 4                                 Bank of Japan
# 5
# 6
# 7
# 8        National Statistics Directorate, Timor             3.4%
# 9     National Statistics Office of Philippines             1.8%
# 10           Department of Statistics, Malaysia              63%
# 11           Department of Statistics, Malaysia            24.4%
# 12           Department of Statistics, Malaysia         MYR20.5B
# 13     Office of Industrial Economics, Thailand           18.46%      19%
# 14                           Statistics Finland              2.7
# 15                   Federal Statistical Office             1.4%     1.5%
# 16                   Federal Statistical Office            10.3%    11.3%
# 17                         Statistics Lithuania             4.5%
# 18                         Statistics Lithuania            35.7%
# 19                            Statistics Norway             0.3%
# 20                            Statistics Norway             2.9%
# 21                            Statistics Norway             0.8%
# 22                            Statistics Sweden             7.2%
# 23                            Statistics Sweden            -1.4%
# 24                            Statistics Sweden             5.7%
# 25                             Markit Economics             66.4
# 26                   Central Bank of Uzbekistan          $-2771M
# 27                   Central Bank of Uzbekistan          $36.22B
# 28                        European Central Bank
# 29  Census and Statistics Department, Hong Kong         H$-31.8B
