# %% [markdown]
# Importing dependencies

# %%
import tradingeconomics as te

# %%
te.login('jupyter:jupyter'); # Signup for a free API key at https://developer.tradingeconomics.com/
# Out:
# 'You are logged in as a jupyter:jupyter'

# %% [markdown]
# Importing data

# %%
df = te.getCalendarData(output_type='df')

# %% [markdown]
# Data manipulation

# %%
df['Hour'] = df['Date'].apply(lambda x: x[11:])
df['Date'] = df['Date'].apply(lambda x: x[:10])
df = df[['Date', 'Hour', 'Country', 'Category', 'Event', 'Source', 'Actual', 'Previous', 'Forecast', ]]
df.sort_values(['Date', 'Hour'], inplace=True)
df.head(30)
# Out:
#           Date Hour         Country                    Category  \
# 0   2021-06-29                Malta                    Holidays
# 1   2021-06-29                 Peru                    Holidays
# 2   2021-06-29           Seychelles                    Holidays
# 3   2021-06-29              Vietnam       Industrial Production
# 4   2021-06-29              Vietnam              Inflation Rate
# 5   2021-06-29              Vietnam            Balance of Trade
# 6   2021-06-29              Vietnam      GDP Annual Growth Rate
# 7   2021-06-29              Vietnam            Tourist Arrivals
# 8   2021-06-29              Vietnam            Retail Sales Yoy
# 9   2021-06-29          Netherlands         Business Confidence
# 10  2021-06-29            Singapore      Producer Prices Change
# 11  2021-06-29            Singapore               Import Prices
# 12  2021-06-29            Singapore               Export Prices
# 13  2021-06-29              Denmark         Business Confidence
# 14  2021-06-29       United Kingdom   Nationwide Housing Prices
# 15  2021-06-29       United Kingdom   Nationwide Housing Prices
# 16  2021-06-29               France         Consumer Confidence
# 17  2021-06-29              Hungary           Unemployment Rate
# 18  2021-06-29             Slovakia         Business Confidence
# 19  2021-06-29             Slovakia         Consumer Confidence
# 20  2021-06-29                Spain  Harmonised Consumer Prices
# 21  2021-06-29                Spain  Harmonised Consumer Prices
# 22  2021-06-29                Spain          Inflation Rate Mom
# 23  2021-06-29                Spain              Inflation Rate
# 24  2021-06-29                Spain            Retail Sales YoY
# 25  2021-06-29                Spain            Retail Sales MoM
# 26  2021-06-29               Sweden      Inflation Expectations
# 27  2021-06-29               Sweden         Business Confidence
# 28  2021-06-29               Sweden         Consumer Confidence
# 29  2021-06-29               Turkey     Economic Optimism Index
#
#                                   Event  \
# 0   Feast of Saint Peter and Saint Paul
# 1   Feast of Saint Peter and Saint Paul
# 2                      Independence Day
# 3             Industrial Production YoY
# 4                    Inflation Rate YoY
# 5                      Balance of Trade
# 6                   GDP Growth Rate YoY
# 7                  Tourist Arrivals YoY
# 8                      Retail Sales YoY
# 9                   Business Confidence
# 10                              PPI YoY
# 11                    Import Prices YoY
# 12                    Export Prices YoY
# 13                  Business Confidence
# 14        Nationwide Housing Prices YoY
# 15        Nationwide Housing Prices MoM
# 16                  Consumer Confidence
# 17                    Unemployment Rate
# 18                  Business Confidence
# 19                  Consumer Confidence
# 20   Harmonised Inflation Rate MoM Prel
# 21   Harmonised Inflation Rate YoY Prel
# 22              Inflation Rate MoM Prel
# 23              Inflation Rate YoY Prel
# 24                     Retail Sales YoY
# 25                     Retail Sales MoM
# 26      Consumer Inflation Expectations
# 27                  Business Confidence
# 28                  Consumer Confidence
# 29            Economic Confidence Index
#
#                                              Source Actual Previous Forecast
# 0
# 1
# 2
# 3              General Statistics Office of Vietnam   6.8%    11.8%
# 4              General Statistics Office of Vietnam  2.40%     2.9%
# 5              General Statistics Office of Vietnam   $-1B  $-2.07B
# 6              General Statistics Office of Vietnam  6.61%    4.65%
# 7              General Statistics Office of Vietnam   -18%   -40.6%
# 8              General Statistics Office of Vietnam  -6.6%      -1%
# 9                            Statistics Netherlands   11.5      8.8
# 10                             Statistics Singapore  18.1%    17.8%
# 11                             Statistics Singapore  13.9%    12.8%
# 12                             Statistics Singapore   9.6%     9.6%
# 13                               Statistics Denmark      4        4
# 14                  Nationwide Building Society, UK  13.4%    10.9%    13.7%
# 15                  Nationwide Building Society, UK   0.7%     1.7%     0.7%
# 16                                    INSEE, France    102       98      100
# 17             Hungarian Central Statistical Office   4.1%     4.3%
# 18        Statistical Office of the Slovak Republic     10      0.3
# 19        Statistical Office of the Slovak Republic  -18.4    -21.1
# 20              National Statistics Institute (INE)   0.4%     0.5%     0.4%
# 21              National Statistics Institute (INE)   2.4%     2.4%     2.4%
# 22              National Statistics Institute (INE)   0.4%     0.5%     0.4%
# 23              National Statistics Institute (INE)   2.6%     2.7%     2.7%
# 24              National Statistics Institute (INE)  19.6%    40.5%
# 25              National Statistics Institute (INE)   0.0%    -0.5%
# 26  National Institute of Economic Research, Sweden   4.3%     4.7%
# 27  National Institute of Economic Research, Sweden  118.8    116.4
# 28  National Institute of Economic Research, Sweden  109.4    112.2
# 29                    Turkish Statistical Institute   97.8     92.6
