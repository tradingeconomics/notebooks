# %% [markdown]
# Importing dependencies

# %%
import tradingeconomics as te

# %%
te.login(); # Signup for a free API key at https://developer.tradingeconomics.com/

# %% [markdown]
# Importing data

# %%
df = te.getCalendarData(output_type='df')

# %% [markdown]
# Data manipulation

# %%
df['Hour'] = df['Date'].apply(lambda x: x[11:])
df['Date'] = df['Date'].apply(lambda x: x[:10])
df = df[['Date', 'Hour', 'Country', 'Category', 'Event', 'Source', 'Actual', 'Previous', 'Forecast', ]]
df.sort_values(['Date', 'Hour'], inplace=True)
df.head(30)
# Out:
#           Date      Hour         Country                   Category  \
# 0   2021-11-05  00:00:00           India                   Holidays
# 1   2021-11-05  00:00:00        Mongolia                   Holidays
# 2   2021-11-05  00:00:00           Nepal                   Holidays
# 3   2021-11-05  00:00:00          Panama                   Holidays
# 4   2021-11-05  00:00:00   United States        Total Vehicle Sales
# 5   2021-11-05  01:00:00     Philippines                    Exports
# 6   2021-11-05  01:00:00     Philippines                    Imports
# 7   2021-11-05  01:00:00     Philippines           Balance of Trade
# 8   2021-11-05  01:00:00     Philippines        Core Inflation Rate
# 9   2021-11-05  01:00:00     Philippines         Inflation Rate Mom
# 10  2021-11-05  01:00:00     Philippines             Inflation Rate
# 11  2021-11-05  01:30:00       Australia              Interest Rate
# 12  2021-11-05  02:00:00       Indonesia            GDP Growth Rate
# 13  2021-11-05  02:00:00       Indonesia     GDP Annual Growth Rate
# 14  2021-11-05  03:00:00       Indonesia  Foreign Exchange Reserves
# 15  2021-11-05  05:00:00       Singapore           Retail Sales YoY
# 16  2021-11-05  05:00:00       Singapore           Retail Sales MoM
# 17  2021-11-05  06:00:00         Estonia             Inflation Rate
# 18  2021-11-05  06:00:00         Estonia         Inflation Rate Mom
# 19  2021-11-05  07:00:00         Denmark  Industrial Production Mom
# 20  2021-11-05  07:00:00         Denmark      Industrial Production
# 21  2021-11-05  07:00:00         Germany  Industrial Production Mom
# 22  2021-11-05  07:00:00            Peru           Balance of Trade
# 23  2021-11-05  07:00:00         Romania           Retail Sales YoY
# 24  2021-11-05  07:00:00         Romania           Retail Sales MoM
# 25  2021-11-05  07:00:00  United Kingdom              Housing Index
# 26  2021-11-05  07:00:00  United Kingdom              Housing Index
# 27  2021-11-05  07:30:00       Euro Area              Interest Rate
# 28  2021-11-05  07:45:00          France   Nonfarm Payrolls Private
# 29  2021-11-05  07:45:00          France  Industrial Production Mom
#
#                                  Event  \
# 0                 Diwali Balipratipada
# 1              Genghis Khan’s Birthday
# 2                       Gobhardan Puja
# 3                            Colon Day
# 4                  Total Vehicle Sales
# 5                          Exports YoY
# 6                          Imports YoY
# 7                     Balance of Trade
# 8              Core Inflation Rate YoY
# 9                   Inflation Rate MoM
# 10                  Inflation Rate YoY
# 11    RBA Statement on Monetary Policy
# 12                 GDP Growth Rate QoQ
# 13                 GDP Growth Rate YoY
# 14           Foreign Exchange Reserves
# 15                    Retail Sales YoY
# 16                    Retail Sales MoM
# 17                  Inflation Rate YoY
# 18                  Inflation Rate MoM
# 19           Industrial Production MoM
# 20           Industrial Production YoY
# 21           Industrial Production MoM
# 22                    Balance of Trade
# 23                    Retail Sales YoY
# 24                    Retail Sales MoM
# 25       Halifax House Price Index MoM
# 26       Halifax House Price Index YoY
# 27               ECB De Guindos Speech
# 28  Private Non Farm Payrolls QoQ Prel
# 29           Industrial Production MoM
#
#                                        Source    Actual  Previous Forecast
# 0
# 1
# 2
# 3
# 4                        Autodata Corporation    12.99M    12.18M
# 5   National Statistics Office of Philippines      6.3%     18.9%
# 6   National Statistics Office of Philippines     24.8%     30.9%
# 7   National Statistics Office of Philippines  $-3.995B  $-3.509B
# 8             Phillipine Statistics Authority      3.4%      3.3%     3.4%
# 9             Phillipine Statistics Authority      0.2%      0.0%    0.48%
# 10            Philippine Statistics Authority      4.6%      4.8%     4.9%
# 11                  Reserve Bank of Australia
# 12                       Statistics Indonesia     1.55%     3.31%     1.8%
# 13                       Statistics Indonesia     3.51%     7.07%    3.76%
# 14                             Bank Indonesia   $145.5B   $146.9B
# 15                       Statistics Singapore      6.6%     -2.8%
# 16                       Statistics Singapore        6%     -0.6%
# 17                         Statistics Estonia      7.0%      6.6%
# 18                         Statistics Estonia     -0.2%      1.2%
# 19                         Statistics Denmark     -5.4%      3.3%
# 20                         Statistics Denmark      4.6%     14.7%
# 21                 Federal Statistical Office     -1.1%     -3.5%       1%
# 22               Central Reserve Bank of Peru    $1590M    $1315M
# 23          Institutul National de Statistica      8.4%     11.3%
# 24          Institutul National de Statistica      0.2%      0.6%
# 25               Halifax and Bank of Scotland      0.9%      1.7%
# 26               Halifax and Bank of Scotland      8.1%      7.4%
# 27                      European Central Bank
# 28                              INSEE, France      0.5%      1.4%
# 29                              INSEE, France     -1.3%        1%       0%
