# %% [markdown]
# # S&P500 Perfomance from 1950 to 2021 and Pandemic Surges around the world

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib as mpl
plt.style.use('seaborn-whitegrid')
import numpy as np
import pandas as pd
from datetime import datetime, timedelta, date
import plotly.graph_objects as go

# %%
import tradingeconomics as te
te.login('jupyter:jupyter')
# Out:
# 'You are logged in as a jupyter:jupyter'

# %% [markdown]
# #### Can we establish some kind of relationship between pandemic outbreaks and the performance of indices like S&P500?
# We intend throughout this notebook to observe 4 pandemics that reached a substantial number of deaths.

# %% [markdown]
# ## Asian Flu (1957)
#
#
# The flu killed approximately 1 million to 2 million people worldwide.

# %%
# data = [
#         {'startDate': datetime.strptime("1957-01-01", '%Y-%m-%d'), 
#          'announce': 'Asian Flu'},
#             ]  
# announcesdf = pd.DataFrame(data) 

# raw_data = te.fetchMarkets(symbol='SPX:IND', initDate='1955-01-01', endDate='1958-12-31', output_type='df')
# treated_data = raw_data.drop(['symbol','high','low','open'], axis=1)
# treated_data=treated_data.rename(columns={'close':'price'})
# fig, ax = plt.subplots(figsize=(20, 10))
# treated_data.plot(ax=ax)

# # Add labels to the plot
# style = dict(size=15, color='black')
# ax.text('1957-1-1', 48, "Asian Flu", **style)

raw_data = te.fetchMarkets(symbol='SPX:IND', initDate='1955-01-01', endDate='1958-12-31', output_type='df')
treated_data = raw_data.drop(['symbol','high','low','open'], axis=1)
treated_data=treated_data.rename(columns={'close':'price'})

def plot(df):
    data = [
        {'startDate': datetime.strptime("1957-01-01", '%Y-%m-%d'), 
         'announce': 'Asian Flu'},
            ]  
    announcesdf = pd.DataFrame(data) 
    fig = go.Figure()
    labels = df.index.tolist()
    line1 = df['price'].values.tolist()
    fig, ax1 = plt.subplots(1,1,figsize=(14,8), dpi= 80)
    for index, row in announcesdf.iterrows():
        #print(row['c1'], row['c2'])
        plt.plot([row['startDate'],row['startDate']],[0,55], lw=3, color ='khaki',zorder=-2)
    ax1.plot(labels, line1, color='darkred')
    ax1.set_xlabel('Date', fontsize=12)
    ax1.tick_params(axis='x', rotation=0, labelsize=12)
    ax1.set_ylabel('Price', color='darkred', fontsize=14)
    ax1.tick_params(axis='y', rotation=0, labelcolor='darkred' )
    ax1.grid(alpha=.3)
    ax1.set_title("S%P 500 and Asian Flu", fontsize=16)
    #ax1.legend()
    fig.tight_layout()
plot(treated_data)

# %% [markdown]
# ## SARS (2002)
# While SARS broke out in Nov. 2002, it did not begin to affect markets until March 2003 after the Chinese authorities reported the SARS outbreak to the World Health Organization. (https://investors-corner.bnpparibas-am.com/investing/coronavirus-lessons-from-sars-for-investors/)

# %%
raw_data = te.fetchMarkets(symbol='SPX:IND', initDate='2000-01-01', endDate='2003-12-31', output_type='df')
treated_data = raw_data.drop(['symbol','high','low','open'], axis=1)
treated_data=treated_data.rename(columns={'close':'price'})

def plot(df):
    data = [
        {'startDate': datetime.strptime("2002-1-1", '%Y-%m-%d'), 
         'announce': 'SARS'},
            ]  
    announcesdf = pd.DataFrame(data) 
    fig = go.Figure()
    labels = df.index.tolist()
    line1 = df['price'].values.tolist()
    fig, ax1 = plt.subplots(1,1,figsize=(14,8), dpi= 80)
    for index, row in announcesdf.iterrows():
        #print(row['c1'], row['c2'])
        plt.plot([row['startDate'],row['startDate']],[0,1600], lw=3, color ='khaki',zorder=-2)
    ax1.plot(labels, line1, color='darkred')
    ax1.set_xlabel('Date', fontsize=12)
    ax1.tick_params(axis='x', rotation=0, labelsize=12)
    ax1.set_ylabel('Price', color='darkred', fontsize=14)
    ax1.tick_params(axis='y', rotation=0, labelcolor='darkred' )
    ax1.grid(alpha=.3)
    ax1.set_title("S%P 500 and SARS", fontsize=16)
    #ax1.legend()
    fig.tight_layout()
plot(treated_data)

# %% [markdown]
# ## EBOLA (2013)
# The Ebola epidemic in West Africa caused 11,310 deaths in Guinea, Liberia, and Sierra Leone, and 15 deaths outside of these three countries. Between December 2013 and February 2014 the S&P 500 fell 5.9%. The sectors most hurt by the epidemic were airlines, cruises, and hotels.
#
#  Shares of American Airlines and Delta Air Lines both dropped 20% in October 2014 after news that an Ebola patient flew the day before being diagnosed.
#
#  https://www.cdc.gov/vhf/ebola/history/2014-2016-outbreak/index.html
#
#  https://money.cnn.com/2014/10/15/investing/ebola-spooks-wall-street-investors-stocks/index.html

# %%
raw_data = te.fetchMarkets(symbol='SPX:IND', initDate='2012-01-01', endDate='2014-12-31', output_type='df')
treated_data = raw_data.drop(['symbol','high','low','open'], axis=1)
treated_data=treated_data.rename(columns={'close':'price'})

def plot(df):
    data = [
        {'startDate': datetime.strptime("2013-1-1", '%Y-%m-%d'), 
         'announce': 'EBOLA'},
            ]  
    announcesdf = pd.DataFrame(data) 
    fig = go.Figure()
    labels = df.index.tolist()
    line1 = df['price'].values.tolist()
    fig, ax1 = plt.subplots(1,1,figsize=(14,8), dpi= 80)
    for index, row in announcesdf.iterrows():
        #print(row['c1'], row['c2'])
        plt.plot([row['startDate'],row['startDate']],[0,1800], lw=3, color ='khaki',zorder=-2)
    ax1.plot(labels, line1, color='darkred')
    ax1.set_xlabel('Date', fontsize=12)
    ax1.tick_params(axis='x', rotation=0, labelsize=12)
    ax1.set_ylabel('Price', color='darkred', fontsize=14)
    ax1.tick_params(axis='y', rotation=0, labelcolor='darkred' )
    ax1.grid(alpha=.3)
    ax1.set_title("S%P 500 and EBOLA", fontsize=16)
    #ax1.legend()
    fig.tight_layout()
plot(treated_data)

# %% [markdown]
# ## COVID-19 (2019)
#
# The global coronavirus pandemic has brought one of the greatest human and economic consequences the world has ever seen. 75.2 million people were infected with the virus worldwide, with a reported 1.67 million deaths as of Dec. 18. In addition, the pandemic is expected to plunge most countries into recession in 2020, with per capita income contracting in the largest fraction of countries globally since 1870.
# https://www.worldbank.org/en/news/feature/2020/06/08/the-global-economic-outlook-during-the-covid-19-pandemic-a-changed-world

# %%
# raw_data = te.fetchMarkets(symbol='SPX:IND', initDate='2018-01-01', endDate='2020-12-31', output_type='df')
# treated_data = raw_data.drop(['symbol','high','low','open'], axis=1)
# treated_data=treated_data.rename(columns={'close':'price'})
# fig, ax = plt.subplots(figsize=(20, 10))
# treated_data.plot(ax=ax)

# data = [
#         {'startDate': datetime.strptime("2019-01-01", '%Y-%m-%d'), 
#          'announce': 'Asian Flu'},
    
#     ]  
 
# announcesdf = pd.DataFrame(data) 


# # Add labels to the plot


raw_data = te.fetchMarkets(symbol='SPX:IND', initDate='2018-01-01', endDate='2020-12-31', output_type='df')
treated_data = raw_data.drop(['symbol','high','low','open'], axis=1)
treated_data=treated_data.rename(columns={'close':'price'})

def plot(df):
    data = [
        {'startDate': datetime.strptime("2019-03-01", '%Y-%m-%d'), 
         'announce': 'COVID-19'},
            ]  
    announcesdf = pd.DataFrame(data) 
    fig = go.Figure()
    labels = df.index.tolist()
    line1 = df['price'].values.tolist()
    fig, ax1 = plt.subplots(1,1,figsize=(14,8), dpi= 80)
    for index, row in announcesdf.iterrows():
        #print(row['c1'], row['c2'])
        plt.plot([row['startDate'],row['startDate']],[0,3700], lw=3, color ='khaki',zorder=-2)
    ax1.plot(labels, line1, color='darkred')
    ax1.set_xlabel('Date', fontsize=12)
    ax1.tick_params(axis='x', rotation=0, labelsize=12)
    ax1.set_ylabel('Price', color='darkred', fontsize=14)
    ax1.tick_params(axis='y', rotation=0, labelcolor='darkred' )
    ax1.grid(alpha=.3)
    ax1.set_title("S%P 500 and COVID-19", fontsize=16)
    style = dict(size=15, color='black')
#     ax1.text('2019-03-12 00:00:00', 3000, "COVID 19", **style)

    #ax1.legend()
    fig.tight_layout()
plot(treated_data)

# %%
# raw_data = te.fetchMarkets(symbol='SPX:IND', initDate='1950-01-01', endDate='2021-08-30', output_type='df')
# treated_data = raw_data.drop(['symbol','high','low','open'], axis=1)
# treated_data=treated_data.rename(columns={'close':'price'})

# fig, ax = plt.subplots(figsize=(20, 10))
# treated_data.plot(ax=ax)

# # Add labels to the plot
# style = dict(size=15, color='red')

# ax.text('1957-1-1', 4, "Asian Flu (Influenza)", **style)
# ax.text('2002-7-4', 1500, "SARS", ha='center', **style)
# ax.text('2013-9-4', 1000, "EBOLA", ha='center', **style)
# ax.text('2018-10-31', 2200, "COVID-19", ha='right', **style)

# # Label the axes
# ax.set(title='S & P 500 and Pandemic Surges (1950-2021)',
#        ylabel='Price')


raw_data = te.fetchMarkets(symbol='SPX:IND', initDate='1950-01-01', endDate='2021-08-30', output_type='df')
treated_data = raw_data.drop(['symbol','high','low','open'], axis=1)
treated_data=treated_data.rename(columns={'close':'price'})

def plot(df):
    data = [
        {'startDate': datetime.strptime("2019-03-01", '%Y-%m-%d'), 
         'announce': 'COVID-19'},
            ]  
    announcesdf = pd.DataFrame(data) 
    fig = go.Figure()
    labels = df.index.tolist()
    
    line1 = df['price'].values.tolist()
    fig, ax1 = plt.subplots(1,1,figsize=(14,8), dpi= 80)
    for index, row in announcesdf.iterrows():
        #print(row['c1'], row['c2'])
        plt.plot([row['startDate'],row['startDate']],[0,4500], lw=3, color ='khaki',zorder=-2)
    ax1.plot(labels, line1, color='darkred')
    ax1.set_xlabel('Date', fontsize=12)
    ax1.tick_params(axis='x', rotation=0, labelsize=12)
    ax1.set_ylabel('Price', color='darkred', fontsize=14)
    ax1.tick_params(axis='y', rotation=0, labelcolor='darkred' )
    ax1.grid(alpha=.3)
    ax1.set_title("S%P 500 and COVID-19", fontsize=16)
    
    #ax1.legend()
    fig.tight_layout()
plot(treated_data)

# %% [markdown]
# ## Conclusion

# %% [markdown]
# It seems to be difficult to determine to what degree these outbreaks interfered with the market. Over the last few decades, we have had a variation in the way technology and science forward the protocols for containing outbreaks, and we also have the growth and transformation from an economy restricted to certain parts of the world to a globalized economic model. It seems possible to suggest that SARS and COVID rather than EBOLA had a large spread area and ended up generating a period of economic downturn. And it also seems to be possible to say that such moments of outbreaks took place at times when there was also a strong economic downturn accompanied by a recovery in less than 10 years.

# %%
raw_data = te.fetchMarkets(symbol='SPX:IND', initDate='1955-01-01', endDate='1958-12-31', output_type='df')
treated_data = raw_data.drop(['symbol','high','low','open'], axis=1)
treated_data=treated_data.rename(columns={'close':'price'})

def plot(df):
    data = [
        {'startDate': datetime.strptime("1957-01-01", '%Y-%m-%d'), 
         'announce': 'Asian Flu'},
            ]  
    announcesdf = pd.DataFrame(data) 
    fig = go.Figure()
    labels = df.index.tolist()
    line1 = df['price'].values.tolist()
    fig, ax1 = plt.subplots(1,1,figsize=(14,8), dpi= 80)
    for index, row in announcesdf.iterrows():
        #print(row['c1'], row['c2'])
        plt.plot([row['startDate'],row['startDate']],[0,55], lw=3, color ='khaki',zorder=-2)
    ax1.plot(labels, line1, color='darkred')
    ax1.set_xlabel('Date', fontsize=12)
    ax1.tick_params(axis='x', rotation=0, labelsize=12)
    ax1.set_ylabel('Price', color='darkred', fontsize=14)
    ax1.tick_params(axis='y', rotation=0, labelcolor='darkred' )
    ax1.grid(alpha=.3)
    ax1.set_title("S%P 500 and Asian Flu", fontsize=16)
    #ax1.legend()
    fig.tight_layout()
plot(treated_data)

# %%
import plotly.graph_objects as go
fig = go.Figure(
    data=[go.Bar(y=[2, 1, 3])],
    layout_title_text="A Figure Displayed with the 'png' Renderer"
)
# fig.show(renderer="png")
fig.show()

# %%
# !pip install --user -U kaleido
# Out:
# Requirement already up-to-date: kaleido in /opt/tljh/user/lib/python3.7/site-packages (0.2.1)

# %%
import plotly.express as px

fig = px.line(x=["a","b","c"], y=[1,3,2], title="sample figure")
print(fig)
fig.show()
# Out:
# Figure({
#     'data': [{'hovertemplate': 'x=%{x}<br>y=%{y}<extra></extra>',
#               'legendgroup': '',
#               'line': {'color': '#636efa', 'dash': 'solid'},
#               'marker': {'symbol': 'circle'},
#               'mode': 'lines',
#               'name': '',
#               'orientation': 'v',
#               'showlegend': False,
#               'type': 'scatter',
#               'x': array(['a', 'b', 'c'], dtype=object),
#               'xaxis': 'x',
#               'y': array([1, 3, 2]),
#               'yaxis': 'y'}],
#     'layout': {'legend': {'tracegroupgap': 0},
#                'template': '...',
#                'title': {'text': 'sample figure'},
#                'xaxis': {'anchor': 'y', 'domain': [0.0, 1.0], 'title': {'text': 'x'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'title': {'text': 'y'}}}
# })

# %%
raw_data = te.fetchMarkets(symbol='SPX:IND', initDate='1950-01-01', endDate='2021-08-30', output_type='df')
treated_data = raw_data.drop(['symbol','high','low','open'], axis=1)
treated_data=treated_data.rename(columns={'close':'price'})
treated_data
# Out:
#                 price
# 2021-08-30  4528.7900
# 2021-08-29  4516.2002
# 2021-08-27  4509.3700
# 2021-08-26  4470.0000
# 2021-08-25  4496.1900
# ...               ...
# 1950-01-07    17.0900
# 1950-01-06    16.9800
# 1950-01-05    16.9300
# 1950-01-04    16.8500
# 1950-01-03    16.6600
#
# [18137 rows x 1 columns]

# %%
labels = treated_data.index.tolist()
line1 = treated_data['price'].values.tolist()

# %%
# Using plotly.express
import plotly.express as px

import pandas as pd
# df = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/finance-charts-apple.csv')
# df =treated_data
# fig = px.line(df, x='Date', y='AAPL.High', range_x=['2016-07-01','2016-12-31'])
fig = px.line(treated_data)
fig.update_layout(
    title='S&P 500 and Pandemic Eras',
    yaxis_title='S&P 500 Stock',
    shapes = [dict(
        x0='1957-01-01', x1='1957-01-01', y0=0, y1=1, xref='x', yref='paper',
        line_width=2), 
             dict(
        x0='2002-01-01', x1='2002-01-01', y0=0, y1=1, xref='x', yref='paper',
        line_width=2),
             dict(
        x0='2013-01-01', x1='2013-01-01', y0=0, y1=1, xref='x', yref='paper',
        line_width=2),
             dict(
        x0='2019-01-01', x1='2019-01-01', y0=0, y1=1, xref='x', yref='paper',
        line_width=2)],
    
    annotations=[dict(
        x='1957-01-01', y=0.05, xref='x', yref='paper',
        showarrow=False, xanchor='left', text='Asian Flu'),
                 dict(
        x='2002-01-01', y=0.05, xref='x', yref='paper',
        showarrow=False, xanchor='left', text='Sars'),
                dict(
        x='2013-01-01', y=0.05, xref='x', yref='paper',
        showarrow=False, xanchor='left', text='Ebola'),
                dict(
        x='2019-01-01', y=0.05, xref='x', yref='paper',
        showarrow=False, xanchor='left', text='Covid-19')]
    
#     annotations=[dict(
#         x='2002-01-01', y=0.05, xref='x', yref='paper',
#         showarrow=False, xanchor='left', text='SARS')]

)
fig.show(renderer='plotly_mimetype')

# %%
fig.show()

# %%
# tennessee.matos@tradingeconomics.com
